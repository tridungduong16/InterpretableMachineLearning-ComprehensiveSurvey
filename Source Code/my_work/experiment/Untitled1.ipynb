# %%
import pyreadr

result = pyreadr.read_r('/home/dtd/Downloads/experimentdatar/data/secrecy.rda') # also works for Rds

# done! let's see what we got
# result is a dictionary where keys are the name of objects and the values python
# objects
print(result.keys()) # let's check what objects we got
df1 = result["secrecy"] # extract the pandas data frame for object df1
# Out:
# odict_keys(['secrecy'])

# %%
df1
# Out:
#       anysecrecytreatment  v_cong_general_10  v_pres_primary_12  \
# 0                       1                  0                  0
# 1                       1                  1                  0
# 2                       1                  0                  0
# 3                       1                  0                  0
# 4                       1                  1                  0
# ...                   ...                ...                ...
# 3739                    1                  0                  0
# 3740                    1                  0                  0
# 3741                    0                  0                  0
# 3742                    0                  0                  0
# 3743                    1                  0                  0
#
#       v_cong_primary_12  v_pres_general_12  turnoutindex_12  badaddress  \
# 0                     0                  0                0           0
# ...

# %%
df1.anysecrecytreatment.value_counts()
# Out:
# 1    2455
# 0    1289
# Name: anysecrecytreatment, dtype: int64

# %%
for i in df1.columns:
    print(i)
# Out:
# anysecrecytreatment
# v_cong_general_10
# v_pres_primary_12
# v_cong_primary_12
# v_pres_general_12
# turnoutindex_12
# badaddress
# town1_block
# town2_block
# town3_block
# town4_block
# town5_block
# town6_block
# i_grp_addr_1
# i_grp_addr_2
# i_grp_addr_3
# i_grp_addr_4
# dem
# rep
# female
# male
# age_md
# age_sq_md
# sosplacebotreatments
