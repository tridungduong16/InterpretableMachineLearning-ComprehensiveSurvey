# %% [markdown]
# ## Import library

# %%
import sys
sys.path.insert(
    1,
    '/home/dtd/Documents/PhD_Life/Source Code/my_work/lib'
)

sys.path.insert(
    1,
    '/home/dtd/Documents/PhD_Life/Source Code/my_work/config'
)

import numpy as np
import pandas as pd
import logging
import dowhy.datasets
import dowhy
import incremental_ps_score_estimator as ipse
import experiment_config as cf
import math
import timeit
import pandas as pd
import numpy as np
import tensorflow as tf
import time
import utils 
from tempfile import TemporaryFile

# save numpy array as npy file
from numpy import asarray
from numpy import save

from dowhy import CausalModel
from sklearn.metrics import log_loss
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import sem
from dowhy import CausalModel
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.neighbors import NearestNeighbors
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import explained_variance_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from tqdm import tqdm
from sklearn.metrics import mean_squared_error
from math import sqrt
from econml.dml import LinearDMLCateEstimator
from sklearn.linear_model import LassoCV
from econml.inference import BootstrapInference
from econml.dml import SparseLinearDMLCateEstimator
from sklearn.linear_model import LassoCV, ElasticNetCV
from sklearn.ensemble import GradientBoostingRegressor
from mlens.ensemble import SuperLearner
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from geneticalgorithm import geneticalgorithm as ga
import logging
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

import pygad
# Out:
# /home/dtd/.conda/envs/phd_env/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/dtd/.conda/envs/phd_env/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# [MLENS] backend: threading

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
treatment = 't'
outcome = 'yf'
col =  ["t", "yf", "ycf", "mu0", "mu1" ]
cov = ["x" + str(i) for i in range(1,26)]
col = col + cov
features = cov + ["t"]

# %% [markdown]
# ## Optimization with Adam and original function

# %%
def incre_ps(delta, data):
    q1 = (delta * data['p1']) / (delta * data['p1'] + data['p0'])
    q1 = tf.math.abs(q1)
    a0 = (1-q1)*data['w0']*(data['cf0'] - data[outcome])
    a1 = q1*data['w1']*(data['cf1'] - data[outcome])    
    influence = a1 - a0
    return tf.reduce_mean(influence)

def optimization(data):
    threhold = tf.constant([0.001])
    delta = tf.Variable(100., trainable = True)
    true_effect = np.mean(data['mu1'] - data['mu0'])
    
    for i in range(150000):
        with tf.GradientTape() as tape:
            influence = incre_ps(delta, data)
            loss = tf.math.abs(true_effect - influence)
            d_delta = tape.gradient(loss, delta)
            opt = tf.keras.optimizers.Adam(learning_rate=0.001)
            opt.apply_gradients(zip([d_delta], [delta]))
            ## early stopping
            if tf.math.less(loss, threhold):
                print("The performance reach MAE: 0.001. Cancelling the training at step {}".format(i))
                break
    return delta, loss

# %% [markdown]
# ### Optimize in train data

# %%
PATH_TRAIN = "/home/dtd/Documents/data/idhp/ihdp_npci_1-100.train.npz"
PATH_TEST = "/home/dtd/Documents/data/idhp/ihdp_npci_1-100.test.npz"

delta_seq = []
losses = []
losses_test = []
for index_ in tqdm(range(1, 101)):
    data = utils.load_data(PATH_TRAIN, index_)
    data_test = utils.load_data(PATH_TEST, index_)
    data_whole = pd.concat([data, data_test], sort=False)

    #oversample = SMOTE()
    #X_train_oversampled, y_train_oversampled = oversample.fit_sample(data_whole[cov].values, data_whole[treatment].values)

    ## Fit treatment
    model_t = LogisticRegression()
    #     model_t.fit(X_train_oversampled, y_train_oversampled)

    ## Fit outcome
    model_y = GradientBoostingRegressor(random_state=0, n_estimators=500)
    model_y.fit(data_whole[features], data_whole[outcome])

    data['p1'] = model_t.predict_proba(data[cov])[:, 1]
    data['p0'] = 1 - data['p1']

    ## Compute counterfactual outcome with no treatment
    data_pos = data.copy()
    data_pos[treatment] = 1
    data['cf1'] = model_y.predict(data_pos[features])

    ## Compute counterfactual outcome with treatment
    data_neg = data.copy()
    data_neg[treatment] = 0
    data['cf0'] = model_y.predict(data_neg[features])

    data['ips_weight'] = (data[treatment] / data['p1'] +
                          (1 - data[treatment]) / (1 - data['p1']))

    data['w0'] = data['ips_weight'] * data[treatment]
    data['w1'] = data['ips_weight'] * (1 - data[treatment])

    delta, loss = optimization(data)
    delta_r = delta.numpy()
    delta_seq.append(delta_r)
    losses.append(loss.numpy())

    influence = ipse.influence_function(data_test, treatment, cov, outcome,
                                        features, delta_r, model_y, model_t)
    means_incre_test, stds_incre = np.mean(influence, axis=0), sem(influence,
                                                                   axis=0)

    true_effect = data['mu1'] - data['mu0']
    means_train, stds = np.mean(true_effect, axis=0), sem(true_effect, axis=0)

    true_effect = data_test['mu1'] - data_test['mu0']
    means_test, stds = np.mean(true_effect, axis=0), sem(true_effect, axis=0)

    mae_test = utils.abs_ate(means_test, means_incre_test)
    losses_test.append(mae_test)
    print("\n")
    print("Data index {}. Delta {:.2f}".format(index_, delta_r))
    print("MAE on traning {:.2f}".format(loss.numpy()))
    print("MAE on testing {:.2f}".format(mae_test))
    print("*" * 100)
# Out:
#   1%|          | 1/100 [08:24<13:53:08, 504.94s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98961
#
#
# Data index 1. Delta 1.09
# MAE on traning 0.00
# MAE on testing 0.65
# ****************************************************************************************************
#   2%|▏         | 2/100 [17:21<14:00:19, 514.48s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98945
#
#
# Data index 2. Delta 1.10
# MAE on traning 0.00
# MAE on testing 0.73
# ****************************************************************************************************
#   3%|▎         | 3/100 [25:50<13:49:09, 512.89s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98784
#
#
# Data index 3. Delta 1.26
# MAE on traning 0.00
# MAE on testing 0.50
# ****************************************************************************************************
#   4%|▍         | 4/100 [35:22<14:08:39, 530.42s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98818
#
#
# Data index 4. Delta 1.23
# MAE on traning 0.00
# MAE on testing 0.62
# ****************************************************************************************************
#   5%|▌         | 5/100 [44:50<14:18:02, 541.92s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99406
#
#
# Data index 5. Delta 0.64
# MAE on traning 0.00
# MAE on testing 0.96
# ****************************************************************************************************
#   6%|▌         | 6/100 [53:06<13:47:06, 527.94s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99219
#
#
# Data index 6. Delta 0.83
# MAE on traning 0.00
# MAE on testing 0.79
# ****************************************************************************************************
#   7%|▋         | 7/100 [1:01:18<13:21:38, 517.19s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99056
#
#
# Data index 7. Delta 0.99
# MAE on traning 0.00
# MAE on testing 0.05
# ****************************************************************************************************
#   8%|▊         | 8/100 [1:09:29<13:01:15, 509.52s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99412
#
#
# Data index 8. Delta 0.64
# MAE on traning 0.00
# MAE on testing 0.47
# ****************************************************************************************************
#   9%|▉         | 9/100 [1:16:59<12:25:23, 491.47s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 89440
#
#
# Data index 9. Delta 10.60
# MAE on traning 0.00
# MAE on testing 3.56
# ****************************************************************************************************
#  10%|█         | 10/100 [1:25:08<12:16:22, 490.91s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98802
#
#
# Data index 10. Delta 1.24
# MAE on traning 0.00
# MAE on testing 0.32
# ****************************************************************************************************
#  11%|█         | 11/100 [1:33:25<12:10:28, 492.45s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99273
#
#
# Data index 11. Delta 0.77
# MAE on traning 0.00
# MAE on testing 0.34
# ****************************************************************************************************
#  12%|█▏        | 12/100 [1:41:52<12:08:43, 496.86s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98857
#
#
# Data index 12. Delta 1.19
# MAE on traning 0.00
# MAE on testing 0.08
# ****************************************************************************************************
#  13%|█▎        | 13/100 [1:50:29<12:09:23, 503.03s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 97165
#
#
# Data index 13. Delta 2.88
# MAE on traning 0.00
# MAE on testing 2.96
# ****************************************************************************************************
#  14%|█▍        | 14/100 [1:58:44<11:57:27, 500.55s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99281
#
#
# Data index 14. Delta 0.77
# MAE on traning 0.00
# MAE on testing 0.77
# ****************************************************************************************************
#  15%|█▌        | 15/100 [2:07:18<11:54:56, 504.67s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99438
#
#
# Data index 15. Delta 0.61
# MAE on traning 0.00
# MAE on testing 0.25
# ****************************************************************************************************
#  16%|█▌        | 16/100 [2:15:36<11:43:30, 502.51s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98755
#
#
# Data index 16. Delta 1.29
# MAE on traning 0.00
# MAE on testing 0.09
# ****************************************************************************************************
#  17%|█▋        | 17/100 [2:23:55<11:33:45, 501.52s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99661
#
#
# Data index 17. Delta 0.39
# MAE on traning 0.00
# MAE on testing 0.57
# ****************************************************************************************************
#  18%|█▊        | 18/100 [2:32:11<11:23:09, 499.88s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99367
#
#
# Data index 18. Delta 0.68
# MAE on traning 0.00
# MAE on testing 0.55
# ****************************************************************************************************
#  19%|█▉        | 19/100 [2:40:26<11:12:45, 498.34s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99167
#
#
# Data index 19. Delta 0.88
# MAE on traning 0.00
# MAE on testing 0.54
# ****************************************************************************************************
#  20%|██        | 20/100 [2:48:40<11:02:41, 497.02s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98827
#
#
# Data index 20. Delta 1.22
# MAE on traning 0.00
# MAE on testing 0.11
# ****************************************************************************************************
#  21%|██        | 21/100 [3:01:10<12:34:32, 573.07s/it]
# Data index 21. Delta 0.32
# MAE on traning 0.00
# MAE on testing 2.15
# ****************************************************************************************************
#  22%|██▏       | 22/100 [3:09:20<11:52:34, 548.14s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99193
#
#
# Data index 22. Delta 0.85
# MAE on traning 0.00
# MAE on testing 0.33
# ****************************************************************************************************
#  23%|██▎       | 23/100 [3:17:48<11:28:01, 536.12s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98903
#
#
# Data index 23. Delta 1.14
# MAE on traning 0.00
# MAE on testing 0.01
# ****************************************************************************************************
#  24%|██▍       | 24/100 [3:26:12<11:06:51, 526.46s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99274
#
#
# Data index 24. Delta 0.77
# MAE on traning 0.00
# MAE on testing 0.69
# ****************************************************************************************************
#  25%|██▌       | 25/100 [3:34:23<10:44:50, 515.88s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98789
#
#
# Data index 25. Delta 1.26
# MAE on traning 0.00
# MAE on testing 0.11
# ****************************************************************************************************
#  26%|██▌       | 26/100 [3:42:28<10:24:34, 506.41s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98538
#
#
# Data index 26. Delta 1.50
# MAE on traning 0.00
# MAE on testing 1.70
# ****************************************************************************************************
#  27%|██▋       | 27/100 [3:50:42<10:11:52, 502.91s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99474
#
#
# Data index 27. Delta 0.57
# MAE on traning 0.00
# MAE on testing 0.25
# ****************************************************************************************************
#  28%|██▊       | 28/100 [3:58:43<9:55:22, 496.15s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 96150
#
#
# Data index 28. Delta 3.89
# MAE on traning 0.00
# MAE on testing 1.46
# ****************************************************************************************************
#  29%|██▉       | 29/100 [4:06:50<9:44:06, 493.62s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99297
#
#
# Data index 29. Delta 0.75
# MAE on traning 0.00
# MAE on testing 0.02
# ****************************************************************************************************
#  30%|███       | 30/100 [4:14:44<9:29:03, 487.77s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98671
#
#
# Data index 30. Delta 1.37
# MAE on traning 0.00
# MAE on testing 1.16
# ****************************************************************************************************
#  31%|███       | 31/100 [4:22:45<9:18:27, 485.61s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98811
#
#
# Data index 31. Delta 1.23
# MAE on traning 0.00
# MAE on testing 0.00
# ****************************************************************************************************
#  32%|███▏      | 32/100 [4:30:42<9:07:17, 482.91s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99311
#
#
# Data index 32. Delta 0.74
# MAE on traning 0.00
# MAE on testing 0.34
# ****************************************************************************************************
#  33%|███▎      | 33/100 [4:38:37<8:56:49, 480.74s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99263
#
#
# Data index 33. Delta 0.78
# MAE on traning 0.00
# MAE on testing 0.76
# ****************************************************************************************************
#  34%|███▍      | 34/100 [4:46:37<8:48:35, 480.54s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99420
#
#
# Data index 34. Delta 0.62
# MAE on traning 0.00
# MAE on testing 0.81
# ****************************************************************************************************
#  35%|███▌      | 35/100 [4:54:35<8:39:30, 479.55s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99670
#
#
# Data index 35. Delta 0.38
# MAE on traning 0.00
# MAE on testing 0.45
# ****************************************************************************************************
#  36%|███▌      | 36/100 [5:02:28<8:29:39, 477.80s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98150
#
#
# Data index 36. Delta 1.89
# MAE on traning 0.00
# MAE on testing 0.05
# ****************************************************************************************************
#  37%|███▋      | 37/100 [5:10:29<8:22:37, 478.69s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99391
#
#
# Data index 37. Delta 0.66
# MAE on traning 0.00
# MAE on testing 2.18
# ****************************************************************************************************
#  38%|███▊      | 38/100 [5:18:23<8:13:16, 477.36s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99280
#
#
# Data index 38. Delta 0.77
# MAE on traning 0.00
# MAE on testing 0.48
# ****************************************************************************************************
#  39%|███▉      | 39/100 [5:26:05<8:00:36, 472.72s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 96808
#
#
# Data index 39. Delta 3.23
# MAE on traning 0.00
# MAE on testing 0.25
# ****************************************************************************************************
#  40%|████      | 40/100 [5:33:58<7:52:48, 472.80s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98537
#
#
# Data index 40. Delta 1.51
# MAE on traning 0.00
# MAE on testing 0.31
# ****************************************************************************************************
#  41%|████      | 41/100 [5:41:59<7:47:17, 475.21s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98763
#
#
# Data index 41. Delta 1.28
# MAE on traning 0.00
# MAE on testing 1.23
# ****************************************************************************************************
#  42%|████▏     | 42/100 [5:49:57<7:40:13, 476.10s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99270
#
#
# Data index 42. Delta 0.78
# MAE on traning 0.00
# MAE on testing 0.06
# ****************************************************************************************************
#  43%|████▎     | 43/100 [5:57:50<7:31:25, 475.19s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98917
#
#
# Data index 43. Delta 1.13
# MAE on traning 0.00
# MAE on testing 0.59
# ****************************************************************************************************
#  44%|████▍     | 44/100 [6:05:49<7:24:25, 476.18s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99563
#
#
# Data index 44. Delta 0.48
# MAE on traning 0.00
# MAE on testing 0.02
# ****************************************************************************************************
#  45%|████▌     | 45/100 [6:17:56<8:25:24, 551.36s/it]
# Data index 45. Delta 0.44
# MAE on traning 0.00
# MAE on testing 0.80
# ****************************************************************************************************
#  46%|████▌     | 46/100 [6:25:50<7:55:23, 528.21s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98055
#
#
# Data index 46. Delta 1.99
# MAE on traning 0.00
# MAE on testing 1.91
# ****************************************************************************************************
#  47%|████▋     | 47/100 [6:33:44<7:32:14, 511.97s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 97916
#
#
# Data index 47. Delta 2.13
# MAE on traning 0.00
# MAE on testing 0.75
# ****************************************************************************************************
#  48%|████▊     | 48/100 [6:41:43<7:15:14, 502.19s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99164
#
#
# Data index 48. Delta 0.88
# MAE on traning 0.00
# MAE on testing 0.64
# ****************************************************************************************************
#  49%|████▉     | 49/100 [6:49:56<7:04:27, 499.35s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98862
#
#
# Data index 49. Delta 1.18
# MAE on traning 0.00
# MAE on testing 0.14
# ****************************************************************************************************
#  50%|█████     | 50/100 [6:58:20<6:57:19, 500.79s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99317
#
#
# Data index 50. Delta 0.73
# MAE on traning 0.00
# MAE on testing 0.49
# ****************************************************************************************************
#  51%|█████     | 51/100 [7:07:09<6:55:57, 509.34s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98813
#
#
# Data index 51. Delta 1.23
# MAE on traning 0.00
# MAE on testing 0.31
# ****************************************************************************************************
#  52%|█████▏    | 52/100 [7:15:47<6:49:27, 511.82s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99226
#
#
# Data index 52. Delta 0.82
# MAE on traning 0.00
# MAE on testing 1.62
# ****************************************************************************************************
#  53%|█████▎    | 53/100 [7:23:52<6:34:31, 503.65s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 97738
#
#
# Data index 53. Delta 2.30
# MAE on traning 0.00
# MAE on testing 0.67
# ****************************************************************************************************
#  54%|█████▍    | 54/100 [7:32:14<6:25:44, 503.15s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98958
#
#
# Data index 54. Delta 1.09
# MAE on traning 0.00
# MAE on testing 0.06
# ****************************************************************************************************
#  55%|█████▌    | 55/100 [7:40:56<6:21:37, 508.82s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99392
#
#
# Data index 55. Delta 0.66
# MAE on traning 0.00
# MAE on testing 0.77
# ****************************************************************************************************
#  56%|█████▌    | 56/100 [7:49:14<6:10:49, 505.68s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99037
#
#
# Data index 56. Delta 1.01
# MAE on traning 0.00
# MAE on testing 0.40
# ****************************************************************************************************
#  57%|█████▋    | 57/100 [7:57:30<6:00:14, 502.66s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99151
#
#
# Data index 57. Delta 0.90
# MAE on traning 0.00
# MAE on testing 0.10
# ****************************************************************************************************
#  58%|█████▊    | 58/100 [8:05:46<5:50:26, 500.64s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98118
#
#
# Data index 58. Delta 1.93
# MAE on traning 0.00
# MAE on testing 0.39
# ****************************************************************************************************
#  59%|█████▉    | 59/100 [8:14:25<5:45:54, 506.20s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98876
#
#
# Data index 59. Delta 1.17
# MAE on traning 0.00
# MAE on testing 0.14
# ****************************************************************************************************
#  60%|██████    | 60/100 [8:23:16<5:42:27, 513.69s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99146
#
#
# Data index 60. Delta 0.90
# MAE on traning 0.00
# MAE on testing 0.75
# ****************************************************************************************************
#  61%|██████    | 61/100 [8:31:18<5:27:40, 504.12s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99209
#
#
# Data index 61. Delta 0.84
# MAE on traning 0.00
# MAE on testing 0.20
# ****************************************************************************************************
#  62%|██████▏   | 62/100 [8:39:24<5:15:49, 498.68s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99386
#
#
# Data index 62. Delta 0.66
# MAE on traning 0.00
# MAE on testing 0.73
# ****************************************************************************************************
#  63%|██████▎   | 63/100 [8:47:30<5:05:16, 495.05s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98752
#
#
# Data index 63. Delta 1.29
# MAE on traning 0.00
# MAE on testing 0.18
# ****************************************************************************************************
#  64%|██████▍   | 64/100 [8:55:40<4:56:03, 493.43s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99668
#
#
# Data index 64. Delta 0.38
# MAE on traning 0.00
# MAE on testing 0.25
# ****************************************************************************************************
#  65%|██████▌   | 65/100 [9:03:44<4:46:12, 490.64s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99334
#
#
# Data index 65. Delta 0.71
# MAE on traning 0.00
# MAE on testing 0.55
# ****************************************************************************************************
#  66%|██████▌   | 66/100 [9:11:54<4:37:59, 490.57s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99014
#
#
# Data index 66. Delta 1.03
# MAE on traning 0.00
# MAE on testing 0.36
# ****************************************************************************************************
#  67%|██████▋   | 67/100 [9:20:03<4:29:25, 489.87s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99097
#
#
# Data index 67. Delta 0.95
# MAE on traning 0.00
# MAE on testing 0.03
# ****************************************************************************************************
#  68%|██████▊   | 68/100 [9:28:36<4:24:56, 496.77s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 105004
#
#
# Data index 68. Delta 204.36
# MAE on traning 0.00
# MAE on testing 3.62
# ****************************************************************************************************
#  69%|██████▉   | 69/100 [9:36:37<4:14:20, 492.27s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99232
#
#
# Data index 69. Delta 0.82
# MAE on traning 0.00
# MAE on testing 0.15
# ****************************************************************************************************
#  70%|███████   | 70/100 [9:44:52<4:06:34, 493.14s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99186
#
#
# Data index 70. Delta 0.86
# MAE on traning 0.00
# MAE on testing 0.58
# ****************************************************************************************************
#  71%|███████   | 71/100 [9:52:49<3:55:58, 488.23s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 97933
#
#
# Data index 71. Delta 2.11
# MAE on traning 0.00
# MAE on testing 0.58
# ****************************************************************************************************
#  72%|███████▏  | 72/100 [10:00:59<3:48:03, 488.68s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99300
#
#
# Data index 72. Delta 0.75
# MAE on traning 0.00
# MAE on testing 0.75
# ****************************************************************************************************
#  73%|███████▎  | 73/100 [10:08:58<3:38:36, 485.78s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99302
#
#
# Data index 73. Delta 0.75
# MAE on traning 0.00
# MAE on testing 0.20
# ****************************************************************************************************
#  74%|███████▍  | 74/100 [10:17:33<3:34:17, 494.51s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99137
#
#
# Data index 74. Delta 0.91
# MAE on traning 0.00
# MAE on testing 0.21
# ****************************************************************************************************
#  75%|███████▌  | 75/100 [10:26:12<3:29:05, 501.83s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99249
#
#
# Data index 75. Delta 0.80
# MAE on traning 0.00
# MAE on testing 1.33
# ****************************************************************************************************
#  76%|███████▌  | 76/100 [10:35:04<3:24:23, 510.96s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98218
#
#
# Data index 76. Delta 1.83
# MAE on traning 0.00
# MAE on testing 0.92
# ****************************************************************************************************
#  77%|███████▋  | 77/100 [10:43:57<3:18:21, 517.46s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98900
#
#
# Data index 77. Delta 1.15
# MAE on traning 0.00
# MAE on testing 0.25
# ****************************************************************************************************
#  78%|███████▊  | 78/100 [10:52:48<3:11:16, 521.66s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99367
#
#
# Data index 78. Delta 0.68
# MAE on traning 0.00
# MAE on testing 0.93
# ****************************************************************************************************
#  79%|███████▉  | 79/100 [11:01:38<3:03:26, 524.13s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98910
#
#
# Data index 79. Delta 1.14
# MAE on traning 0.00
# MAE on testing 0.51
# ****************************************************************************************************
#  80%|████████  | 80/100 [11:10:28<2:55:18, 525.94s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99327
#
#
# Data index 80. Delta 0.72
# MAE on traning 0.00
# MAE on testing 0.39
# ****************************************************************************************************
#  81%|████████  | 81/100 [11:18:26<2:42:01, 511.65s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 90022
#
#
# Data index 81. Delta 10.02
# MAE on traning 0.00
# MAE on testing 3.60
# ****************************************************************************************************
#  82%|████████▏ | 82/100 [11:27:02<2:33:49, 512.74s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 100111
#
#
# Data index 82. Delta 0.16
# MAE on traning 0.00
# MAE on testing 0.65
# ****************************************************************************************************
#  83%|████████▎ | 83/100 [11:35:25<2:24:28, 509.92s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98361
#
#
# Data index 83. Delta 1.69
# MAE on traning 0.00
# MAE on testing 2.27
# ****************************************************************************************************
#  84%|████████▍ | 84/100 [11:48:43<2:39:02, 596.41s/it]
# Data index 84. Delta 0.15
# MAE on traning 0.00
# MAE on testing 0.15
# ****************************************************************************************************
#  85%|████████▌ | 85/100 [12:02:02<2:44:15, 657.06s/it]
# Data index 85. Delta 235.53
# MAE on traning 5.80
# MAE on testing 6.06
# ****************************************************************************************************
#  86%|████████▌ | 86/100 [12:10:49<2:24:11, 617.93s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99028
#
#
# Data index 86. Delta 1.01
# MAE on traning 0.00
# MAE on testing 3.07
# ****************************************************************************************************
#  87%|████████▋ | 87/100 [12:19:30<2:07:36, 588.98s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 97942
#
#
# Data index 87. Delta 2.10
# MAE on traning 0.00
# MAE on testing 0.77
# ****************************************************************************************************
#  88%|████████▊ | 88/100 [12:28:10<1:53:38, 568.19s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99032
#
#
# Data index 88. Delta 1.02
# MAE on traning 0.00
# MAE on testing 0.64
# ****************************************************************************************************
#  89%|████████▉ | 89/100 [12:36:56<1:41:51, 555.59s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99321
#
#
# Data index 89. Delta 0.73
# MAE on traning 0.00
# MAE on testing 1.21
# ****************************************************************************************************
#  90%|█████████ | 90/100 [12:45:31<1:30:34, 543.49s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99120
#
#
# Data index 90. Delta 0.93
# MAE on traning 0.00
# MAE on testing 0.23
# ****************************************************************************************************
#  91%|█████████ | 91/100 [12:53:59<1:19:56, 532.90s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98753
#
#
# Data index 91. Delta 1.30
# MAE on traning 0.00
# MAE on testing 0.66
# ****************************************************************************************************
#  92%|█████████▏| 92/100 [13:02:19<1:09:44, 523.05s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99560
#
#
# Data index 92. Delta 0.49
# MAE on traning 0.00
# MAE on testing 0.06
# ****************************************************************************************************
#  93%|█████████▎| 93/100 [13:09:24<57:34, 493.49s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 84687
#
#
# Data index 93. Delta 15.36
# MAE on traning 0.00
# MAE on testing 1.45
# ****************************************************************************************************
#  94%|█████████▍| 94/100 [13:17:46<49:36, 496.02s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99011
#
#
# Data index 94. Delta 1.04
# MAE on traning 0.00
# MAE on testing 0.85
# ****************************************************************************************************
#  95%|█████████▌| 95/100 [13:26:10<41:32, 498.52s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99506
#
#
# Data index 95. Delta 0.54
# MAE on traning 0.00
# MAE on testing 0.66
# ****************************************************************************************************
#  96%|█████████▌| 96/100 [13:34:42<33:29, 502.49s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99039
#
#
# Data index 96. Delta 1.01
# MAE on traning 0.00
# MAE on testing 0.38
# ****************************************************************************************************
#  97%|█████████▋| 97/100 [13:43:08<25:10, 503.61s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98816
#
#
# Data index 97. Delta 1.23
# MAE on traning 0.00
# MAE on testing 0.52
# ****************************************************************************************************
#  98%|█████████▊| 98/100 [13:50:37<16:14, 487.05s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 90199
#
#
# Data index 98. Delta 9.84
# MAE on traning 0.00
# MAE on testing 1.95
# ****************************************************************************************************
#  99%|█████████▉| 99/100 [13:58:48<08:08, 488.40s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 99115
#
#
# Data index 99. Delta 0.93
# MAE on traning 0.00
# MAE on testing 0.44
# ****************************************************************************************************
# 100%|██████████| 100/100 [14:06:55<00:00, 508.16s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 98596
#
#
# Data index 100. Delta 1.45
# MAE on traning 0.00
# MAE on testing 0.22
# ****************************************************************************************************

# %%
print("MAE Training {:.4f}".format(np.mean(losses)))
print("MAE Testing {:.4f}".format(np.mean(losses_test)))
# Out:
# MAE Training 0.0586
# MAE Testing 0.7886

# %%
# MAE Training 0.1605
# MAE Testing 0.5021

### optimize train-test together
# MAE Training 0.0933
# MAE Testing 0.6035

# %%
data = asarray(delta_seq)
save('delta_.npy', delta_seq)

# %%
PATH_TRAIN = "/home/dtd/Documents/data/idhp/ihdp_npci_1-100.train.npz"
PATH_TEST = "/home/dtd/Documents/data/idhp/ihdp_npci_1-100.test.npz"

delta_seq = []
losses = []
losses_test = []
for index_ in tqdm(range(1, 101)): 
    data = utils.load_data(PATH_TRAIN, index_)
    data_test = utils.load_data(PATH_TEST, index_)
    data_whole = pd.concat([data, data_test], sort=False)
    
    #oversample = SMOTE()
    #X_train_oversampled, y_train_oversampled = oversample.fit_sample(data_whole[cov].values, data_whole[treatment].values)
    
    ## Fit treatment
    model_t = LogisticRegression()
    #model_t.fit(X_train_oversampled, y_train_oversampled)

    ## Fit outcome
    model_y = GradientBoostingRegressor(random_state=0, n_estimators = 500)
    model_y.fit(data_whole[features], data_whole[outcome])

    data['p1'] = model_t.predict_proba(data[cov])[:,1]
    data['p0'] = 1 - data['p1']

    ## Compute counterfactual outcome with no treatment
    data_pos = data.copy()
    data_pos[treatment] = 1
    data['cf1'] = model_y.predict(data_pos[features])

    ## Compute counterfactual outcome with treatment
    data_neg = data.copy()
    data_neg[treatment] = 0
    data['cf0'] = model_y.predict(data_neg[features])

    data['ips_weight'] = (data[treatment] / data['p1'] + (1 - data[treatment]) /
                          (1 - data['p1']))
    
    data['w0'] = data['ips_weight']*data[treatment]
    data['w1'] = data['ips_weight']*(1 - data[treatment])
    
    delta, loss = optimization(data)
    delta_r = delta.numpy()
    delta_seq.append(delta_r)
    losses.append(loss.numpy())
    
    
    influence = ipse.influence_function(data_test, treatment, cov, outcome, features, delta_r, model_y, model_t)
    means_incre_test, stds_incre = np.mean(influence, axis=0), sem(influence, axis=0)

    true_effect = data['mu1'] - data['mu0']
    means_train, stds = np.mean(true_effect, axis=0), sem(true_effect, axis=0)
    
    true_effect = data_test['mu1'] - data_test['mu0']
    means_test, stds = np.mean(true_effect, axis=0), sem(true_effect, axis=0)

    mae_test = utils.abs_ate(means_test, means_incre_test)
    losses_test.append(mae_test)
    print("\n")
    print("Data index {}. Delta {:.2f}".format(index_, delta_r))
    print("MAE on traning {:.2f}".format(loss.numpy()))
    print("MAE on testing {:.2f}".format(mae_test))
    print("*"*100)

# %% [markdown]
# ## Optimization with list of delta

# %%
def incre_ps(delta, data):
    q1 = (delta * data['p1']) / (delta * data['p1'] + data['p0'])
    q1 = tf.math.abs(q1)
    a0 = (1-q1)*data['w0']*(data['cf0'] - data[outcome])
    a1 = q1*data['w1']*(data['cf1'] - data[outcome])    
    influence = a1 - a0
    return tf.reduce_mean(influence)

def optimization(data):
    threhold = tf.constant([0.001])
    '''
    delta = tf.Variable(
        tf.random.uniform([data.shape[0],], 
                          minval=1, 
                          maxval=100, 
                          dtype=tf.dtypes.float32), 
                          trainable = True)
    '''
    delta = tf.Variable(tf.random.normal(
        [data.shape[0],], 
        mean=0.0, 
        stddev=1.0, 
        dtype=tf.dtypes.float32, 
        seed=1, 
        name='delta'
    ), trainable = True)
    
    true_effect = np.mean(data['mu1'] - data['mu0'])
    
    for i in range(50000):
        with tf.GradientTape() as tape:
            influence = incre_ps(delta, data)
            loss = tf.math.abs(true_effect - influence)
            d_delta = tape.gradient(loss, delta)
            opt = tf.keras.optimizers.Adam(learning_rate=0.001)
            opt.apply_gradients(zip([d_delta], [delta]))
            ## early stopping
            if tf.math.less(loss, threhold):
                print("The performance reach MAE: 0.001. Cancelling the training at step {}".format(i))
                break
    return delta, loss

# %% [markdown]
# ### Optimize in train data

# %%
PATH_TRAIN = "/home/dtd/Documents/interpretable_machine_learning/Source Code/data/ihdp_npci_1-100.train.npz"
PATH_TEST = "/home/dtd/Documents/interpretable_machine_learning/Source Code/data/ihdp_npci_1-100.test.npz"

delta_seq = []
for index_ in tqdm(range(1, 10)): 
    data = utils.load_data(PATH_TRAIN, index_)
    ## Fit treatment
    model_t = LogisticRegression()
    model_t.fit(data[cov], data[treatment])

    ## Fit outcome
    model_y = GradientBoostingRegressor(random_state=0, n_estimators = 5000)
    model_y.fit(data[features], data[outcome])

    data['p1'] = model_t.predict_proba(data[cov])[:,1]
    data['p0'] = 1 - data['p1']

    ## Compute counterfactual outcome with no treatment
    data_pos = data.copy()
    data_pos[treatment] = 1
    data['cf1'] = model_y.predict(data_pos[features])

    ## Compute counterfactual outcome with treatment
    data_neg = data.copy()
    data_neg[treatment] = 0
    data['cf0'] = model_y.predict(data_neg[features])

    data['ips_weight'] = (data[treatment] / data['p1'] + (1 - data[treatment]) /
                          (1 - data['p1']))
    
    data['w0'] = data['ips_weight']*data[treatment]
    data['w1'] = data['ips_weight']*(1 - data[treatment])
    
    delta, loss = optimization(data)
    delta_r = delta.numpy()
    print(delta_r.shape)
    delta_seq.append(delta_r)
    print("Data index {}. Loss {:.2f}".format(index_, loss.numpy()))
# Out:
#  11%|█         | 1/9 [04:49<38:39, 289.88s/it]
# (672,)
# Data index 1. Loss 0.00
#  22%|██▏       | 2/9 [04:54<23:50, 204.32s/it]
# The performance reach MAE: 0.001. Cancelling the training at step 31
# (672,)
# Data index 2. Loss 0.00
#  33%|███▎      | 3/9 [09:35<22:43, 227.29s/it]
# (672,)
# Data index 3. Loss 0.01
#  44%|████▍     | 4/9 [14:23<20:27, 245.46s/it]
# (672,)
# Data index 4. Loss 0.00
#  56%|█████▌    | 5/9 [19:06<17:06, 256.68s/it]
# (672,)
# Data index 5. Loss 0.01
#  67%|██████▋   | 6/9 [23:53<13:17, 265.96s/it]
# (672,)
# Data index 6. Loss 0.02
#  78%|███████▊  | 7/9 [28:45<09:07, 273.58s/it]
# (672,)
# Data index 7. Loss 0.05
#  89%|████████▉ | 8/9 [33:31<04:37, 277.51s/it]
# (672,)
# Data index 8. Loss 0.02
# 100%|██████████| 9/9 [38:27<00:00, 256.36s/it]
# (672,)
# Data index 9. Loss 0.26

# %%
np.array(delta_seq).shape
# Out:
# (9, 672)

# %%
save('list_delta_.npy', delta_seq)

# %% [markdown]
# ## Optimization for individual treatment effect

# %%
def incre_ps(delta, data):
    q1 = (delta * data['p1']) / (delta * data['p1'] + data['p0'])
    q1 = tf.math.abs(q1)
    a0 = (1-q1)*data['w0']*(data['cf0'] - data[outcome])
    a1 = q1*data['w1']*(data['cf1'] - data[outcome])    
    influence = a1 - a0
    return influence

def optimization(data):
    threhold = tf.constant([0.01])
    '''
    delta = tf.Variable(
        tf.random.uniform([data.shape[0],], 
                          minval=1, 
                          maxval=100, 
                          dtype=tf.dtypes.float32), 
                          trainable = True)
    '''
    delta = tf.Variable(tf.random.normal(
        [data.shape[0],], 
        mean=0, 
        stddev=10, 
        dtype=tf.dtypes.float32, 
        seed=1, 
        name='delta'
    ), trainable = True)
    
    true_effect = data['mu1'] - data['mu0']
    
    for i in range(100000):
        with tf.GradientTape() as tape:
            influence = incre_ps(delta, data)
            loss = tf.keras.losses.MAE(true_effect, influence)
            d_delta = tape.gradient(loss, delta)
            opt = tf.keras.optimizers.Adam(learning_rate=0.001)
            opt.apply_gradients(zip([d_delta], [delta]))
            if i % 1000 == 0:
                print("Epoch {}. Loss {:.5f}".format(i, loss.numpy()))
            if tf.math.less(loss, threhold):
                print("The performance reach MAE: 0.001. Cancelling the training at step {}".format(i))
                break
    return delta, loss

# %%
PATH_TRAIN = "/home/dtd/Documents/interpretable_machine_learning/Source Code/data/ihdp_npci_1-100.train.npz"
PATH_TEST = "/home/dtd/Documents/interpretable_machine_learning/Source Code/data/ihdp_npci_1-100.test.npz"

delta_seq = []
for index_ in tqdm(range(13, 14)): 
    data = utils.load_data(PATH_TRAIN, index_)
    ## Fit treatment
    model_t = LogisticRegression()
    model_t.fit(data[cov], data[treatment])

    ## Fit outcome
    model_y = GradientBoostingRegressor(random_state=0, n_estimators = 5000)
    model_y.fit(data[features], data[outcome])

    data['p1'] = model_t.predict_proba(data[cov])[:,1]
    data['p0'] = 1 - data['p1']

    ## Compute counterfactual outcome with no treatment
    data_pos = data.copy()
    data_pos[treatment] = 1
    data['cf1'] = model_y.predict(data_pos[features])

    ## Compute counterfactual outcome with treatment
    data_neg = data.copy()
    data_neg[treatment] = 0
    data['cf0'] = model_y.predict(data_neg[features])

    data['ips_weight'] = (data[treatment] / data['p1'] + (1 - data[treatment]) /
                          (1 - data['p1']))
    
    data['w0'] = data['ips_weight']*data[treatment]
    data['w1'] = data['ips_weight']*(1 - data[treatment])
    
    delta, loss = optimization(data)
    delta_r = delta.numpy()
    delta_seq.append(delta_r)
    print("Data index {}. Loss {:.2f}".format(index_, loss.numpy()))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0. Loss 128.21106
# Epoch 1000. Loss 35.25104
# Epoch 2000. Loss 26.33487
# Epoch 3000. Loss 22.03906
# Epoch 4000. Loss 19.51452
# Epoch 5000. Loss 17.79730
# Epoch 6000. Loss 16.47934
# Epoch 7000. Loss 15.40867
# Epoch 8000. Loss 14.58724
# Epoch 9000. Loss 13.90437
# Epoch 10000. Loss 13.29880
# Epoch 11000. Loss 12.75287
# Epoch 12000. Loss 12.24901
# Epoch 13000. Loss 11.83835
# Epoch 14000. Loss 11.50295
# Epoch 15000. Loss 11.18480
# Epoch 16000. Loss 10.90050
# Epoch 17000. Loss 10.66358
# Epoch 18000. Loss 10.45095
# Epoch 19000. Loss 10.25655
# Epoch 20000. Loss 10.07695
# Epoch 21000. Loss 9.91892
# Epoch 22000. Loss 9.77304
# Epoch 23000. Loss 9.63611
# Epoch 24000. Loss 9.50814
# Epoch 25000. Loss 9.38981
# Epoch 26000. Loss 9.27811
# Epoch 27000. Loss 9.17255
# Epoch 28000. Loss 9.07324
# Epoch 29000. Loss 8.97934
# Epoch 30000. Loss 8.89013
# Epoch 31000. Loss 8.80546
# Epoch 32000. Loss 8.72501
# Epoch 33000. Loss 8.64893
# Epoch 34000. Loss 8.57677
# Epoch 35000. Loss 8.50806
# Epoch 36000. Loss 8.44242
# Epoch 37000. Loss 8.37966
# Epoch 38000. Loss 8.31963
# Epoch 39000. Loss 8.26250
# Epoch 40000. Loss 8.20809
# Epoch 41000. Loss 8.15584
# Epoch 42000. Loss 8.10573
# Epoch 43000. Loss 8.05758
# Epoch 44000. Loss 8.01163
# Epoch 45000. Loss 7.96834
# Epoch 46000. Loss 7.92674
# Epoch 47000. Loss 7.88663
# Epoch 48000. Loss 7.84795
# Epoch 49000. Loss 7.81053
# Epoch 50000. Loss 7.77444
# Epoch 51000. Loss 7.73965
# Epoch 52000. Loss 7.70595
# Epoch 53000. Loss 7.67409
# Epoch 54000. Loss 7.64323
# Epoch 55000. Loss 7.61338
# Epoch 56000. Loss 7.58440
# Epoch 57000. Loss 7.55627
# Epoch 58000. Loss 7.52914
# Epoch 59000. Loss 7.50283
# Epoch 60000. Loss 7.47723
# Epoch 61000. Loss 7.45239
# Epoch 62000. Loss 7.42889
# Epoch 63000. Loss 7.40609
# Epoch 64000. Loss 7.38403
# Epoch 65000. Loss 7.36268
# Epoch 66000. Loss 7.34194
# Epoch 67000. Loss 7.32175
# Epoch 68000. Loss 7.30209
# Epoch 69000. Loss 7.28293
# Epoch 70000. Loss 7.26449
# Epoch 71000. Loss 7.24649
# Epoch 72000. Loss 7.22891
# Epoch 73000. Loss 7.21174
# Epoch 74000. Loss 7.19496
# Epoch 75000. Loss 7.17856
# Epoch 76000. Loss 7.16253
# Epoch 77000. Loss 7.14686
# Epoch 78000. Loss 7.13159
# Epoch 79000. Loss 7.11670
# Epoch 80000. Loss 7.10213
# Epoch 81000. Loss 7.08787
# Epoch 82000. Loss 7.07391
# Epoch 83000. Loss 7.06024
# Epoch 84000. Loss 7.04697
# Epoch 85000. Loss 7.03399
# Epoch 86000. Loss 7.02127
# Epoch 87000. Loss 7.00881
# Epoch 88000. Loss 6.99659
# Epoch 89000. Loss 6.98461
# Epoch 90000. Loss 6.97286
# Epoch 91000. Loss 6.96134
# Epoch 92000. Loss 6.95009
# Epoch 93000. Loss 6.93910
# Epoch 94000. Loss 6.92838
# Epoch 95000. Loss 6.91798
# Epoch 96000. Loss 6.90786
# Epoch 97000. Loss 6.89798
# Epoch 98000. Loss 6.88830
# Epoch 99000. Loss 6.87881
# 100%|██████████| 1/1 [09:38<00:00, 578.35s/it]
# Data index 13. Loss 6.87

# %%
save('individual_list_delta_.npy', delta_seq)

# %% [markdown]
# ## Optimization for individual treatment effects using genetic algorithm

# %%
def incre_ps(delta, data):
    q1 = (delta * data['p1']) / (delta * data['p1'] + data['p0'])
    q1 = abs(q1)
    a0 = (1-q1)*data['w0']*(data['cf0'] - data[outcome])
    a1 = q1*data['w1']*(data['cf1'] - data[outcome])    
    influence = a1 - a0
    return influence


def fitness_function(delta, solution_idx):
    influence = incre_ps(delta, data)
    mae = -np.sqrt(np.mean((true_effect - influence)**2))
    return np.mean(mae)

# %%
PATH_TRAIN = "/home/dtd/Documents/interpretable_machine_learning/Source Code/data/ihdp_npci_1-100.train.npz"
data = utils.load_data(PATH_TRAIN, 1)

## Fit treatment
model_t = LogisticRegression()
model_t.fit(data[cov], data[treatment])

## Fit outcome
model_y = GradientBoostingRegressor(random_state=0, n_estimators = 5000)
model_y.fit(data[features], data[outcome])

data['p1'] = model_t.predict_proba(data[cov])[:,1]
data['p0'] = 1 - data['p1']

## Compute counterfactual outcome with no treatment
data_pos = data.copy()
data_pos[treatment] = 1
data['cf1'] = model_y.predict(data_pos[features])

## Compute counterfactual outcome with treatment
data_neg = data.copy()
data_neg[treatment] = 0
data['cf0'] = model_y.predict(data_neg[features])

data['ips_weight'] = (data[treatment] / data['p1'] + (1 - data[treatment]) /
                      (1 - data['p1']))

data['w0'] = data['ips_weight']*data[treatment]
data['w1'] = data['ips_weight']*(1 - data[treatment])

# %%
true_effect = data['mu1'] - data['mu0']

# %%
"""
Given the following function:
    y = f(w1:w6) = w1x1 + w2x2 + w3x3 + w4x4 + w5x5 + 6wx6
    where (x1,x2,x3,x4,x5,x6)=(4,-2,3.5,5,-11,-4.7) and y=44
What are the best values for the 6 weights (w1 to w6)? We are going to use the genetic algorithm to optimize this function.
"""

#function_inputs = [4,-2,3.5,5,-11,-4.7] # Function inputs.
#desired_output = 44 # Function output.

function_inputs = np.random.rand(data.shape[0]) # Function inputs.

num_generations = 5000 # Number of generations.
num_parents_mating = 100 # Number of solutions to be selected as parents in the mating pool.

# To prepare the initial population, there are 2 ways:
# 1) Prepare it yourself and pass it to the initial_population parameter. This way is useful when the user wants to start the genetic algorithm with a custom initial population.
# 2) Assign valid integer values to the sol_per_pop and num_genes parameters. If the initial_population parameter exists, then the sol_per_pop and num_genes parameters are useless.
sol_per_pop = 2500 # Number of solutions in the population.
num_genes = len(function_inputs)

init_range_low = -100
init_range_high = 100

parent_selection_type = "sss" # Type of parent selection.
keep_parents = -1 # Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.

crossover_type = "single_point" # Type of the crossover operator.

# Parameters of the mutation operation.
mutation_type = "random" # Type of the mutation operator.
mutation_percent_genes = 10 # Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists or when mutation_type is None.

last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    print("\n")
    last_fitness = ga_instance.best_solution()[1]

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating, 
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       keep_parents=keep_parents,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       callback_generation=callback_generation)

# Running the GA to optimize the parameters of the function.
ga_instance.run()
# Out:
# Generation = 1
# Fitness    = -4.678022693269469
# Change     = -4.678022693269469
#
#
# Generation = 2
# Fitness    = -4.199850401935463
# Change     = 0.47817229133400563
#
#
# Generation = 3
# Fitness    = -4.175215930641381
# Change     = 0.024634471294081806
#
#
# Generation = 4
# Fitness    = -4.164173382619324
# Change     = 0.01104254802205773
#
#
# Generation = 5
# Fitness    = -4.145008518945877
# Change     = 0.019164863673446497
#
#
# Generation = 6
# Fitness    = -4.125295674564733
# Change     = 0.019712844381143846
#
#
# Generation = 7
# Fitness    = -4.091384158461873
# Change     = 0.033911516102860695
#
#
# Generation = 8
# Fitness    = -4.0773945236537825
# Change     = 0.013989634808090123
#
#
# Generation = 9
# Fitness    = -4.060551485801685
# Change     = 0.016843037852097176
#
#
# Generation = 10
# Fitness    = -4.045882846912978
# Change     = 0.014668638888707619
#
#
# Generation = 11
# Fitness    = -4.017605397804122
# Change     = 0.02827744910885599
#
#
# Generation = 12
# Fitness    = -4.002593999633785
# Change     = 0.015011398170337031
#
#
# Generation = 13
# Fitness    = -3.9972408320410575
# Change     = 0.005353167592727193
#
#
# Generation = 14
# Fitness    = -3.986121171506238
# Change     = 0.011119660534819609
#
#
# Generation = 15
# Fitness    = -3.9824339205612613
# Change     = 0.0036872509449765722
#
#
# Generation = 16
# Fitness    = -3.8605362177065574
# Change     = 0.12189770285470392
#
#
# Generation = 17
# Fitness    = -3.8560643709101026
# Change     = 0.004471846796454848
#
#
# Generation = 18
# Fitness    = -3.846167910310642
# Change     = 0.009896460599460699
#
#
# Generation = 19
# Fitness    = -3.8415288866742543
# Change     = 0.004639023636387574
#
#
# Generation = 20
# Fitness    = -3.8360978872377602
# Change     = 0.005430999436494055
#
#
# Generation = 21
# Fitness    = -3.825832993131968
# Change     = 0.010264894105792344
#
#
# Generation = 22
# Fitness    = -3.7003532470245224
# Change     = 0.1254797461074455
#
#
# Generation = 23
# Fitness    = -3.691845037796302
# Change     = 0.008508209228220487
#
#
# Generation = 24
# Fitness    = -3.688069036518246
# Change     = 0.003776001278056107
#
#
# Generation = 25
# Fitness    = -3.674148640359419
# Change     = 0.013920396158826787
#
#
# Generation = 26
# Fitness    = -3.6315703861758584
# Change     = 0.04257825418356065
#
#
# Generation = 27
# Fitness    = -3.6196524120885565
# Change     = 0.011917974087301886
#
#
# Generation = 28
# Fitness    = -3.6114294957371005
# Change     = 0.008222916351456
#
#
# Generation = 29
# Fitness    = -3.6043853779281254
# Change     = 0.00704411780897507
#
#
# Generation = 30
# Fitness    = -3.5987550246636615
# Change     = 0.005630353264463928
#
#
# Generation = 31
# Fitness    = -3.5782031838583475
# Change     = 0.020551840805314026
#
#
# Generation = 32
# Fitness    = -3.573967351481283
# Change     = 0.004235832377064597
#
#
# Generation = 33
# Fitness    = -3.5524890420253588
# Change     = 0.021478309455924105
#
#
# Generation = 34
# Fitness    = -3.5448584140950654
# Change     = 0.007630627930293343
#
#
# Generation = 35
# Fitness    = -3.5393991612079856
# Change     = 0.005459252887079824
#
#
# Generation = 36
# Fitness    = -3.534103464416847
# Change     = 0.005295696791138393
#
#
# Generation = 37
# Fitness    = -3.5217259301373476
# Change     = 0.012377534279499613
#
#
# Generation = 38
# Fitness    = -3.515006460391391
# Change     = 0.006719469745956719
#
#
# Generation = 39
# Fitness    = -3.505562668185502
# Change     = 0.009443792205888979
#
#
# Generation = 40
# Fitness    = -3.4960908185867376
# Change     = 0.009471849598764237
#
#
# Generation = 41
# Fitness    = -3.480567355559454
# Change     = 0.01552346302728358
#
#
# Generation = 42
# Fitness    = -3.47969307606772
# Change     = 0.0008742794917342422
#
#
# Generation = 43
# Fitness    = -3.477215736005199
# Change     = 0.00247734006252065
#
#
# Generation = 44
# Fitness    = -3.4697787733115555
# Change     = 0.0074369626936436894
#
#
# Generation = 45
# Fitness    = -3.4653340972909943
# Change     = 0.0044446760205612
#
#
# Generation = 46
# Fitness    = -3.4649737972390664
# Change     = 0.0003603000519278865
#
#
# Generation = 47
# Fitness    = -3.455085220165834
# Change     = 0.00988857707323243
#
#
# Generation = 48
# Fitness    = -3.453845303280574
# Change     = 0.0012399168852601505
#
#
# Generation = 49
# Fitness    = -3.4510649041585064
# Change     = 0.0027803991220674007
#
#
# Generation = 50
# Fitness    = -3.44743148035222
# Change     = 0.0036334238062862845
#
#
# Generation = 51
# Fitness    = -3.4425687098095383
# Change     = 0.004862770542681805
#
#
# Generation = 52
# Fitness    = -3.440900836922613
# Change     = 0.0016678728869252701
#
#
# Generation = 53
# Fitness    = -3.4266451870161996
# Change     = 0.014255649906413481
#
#
# Generation = 54
# Fitness    = -3.423123211885607
# Change     = 0.0035219751305923808
#
#
# Generation = 55
# Fitness    = -3.4150687602887535
# Change     = 0.008054451596853696
#
#
# Generation = 56
# Fitness    = -3.4120670192208435
# Change     = 0.0030017410679099576
#
#
# Generation = 57
# Fitness    = -3.4043121934802505
# Change     = 0.007754825740593052
#
#
# Generation = 58
# Fitness    = -3.4042191362329652
# Change     = 9.305724728525533e-05
#
#
# Generation = 59
# Fitness    = -3.4022455489170125
# Change     = 0.001973587315952763
#
#
# Generation = 60
# Fitness    = -3.396326923418617
# Change     = 0.005918625498395613
#
#
# Generation = 61
# Fitness    = -3.381933853148791
# Change     = 0.014393070269826058
#
#
# Generation = 62
# Fitness    = -3.3780935805389376
# Change     = 0.0038402726098532014
#
#
# Generation = 63
# Fitness    = -3.374330300778422
# Change     = 0.003763279760515381
#
#
# Generation = 64
# Fitness    = -3.370691132273742
# Change     = 0.003639168504680157
#
#
# Generation = 65
# Fitness    = -3.3639450992923585
# Change     = 0.006746032981383543
#
#
# Generation = 66
# Fitness    = -3.361973048600677
# Change     = 0.001972050691681382
#
#
# Generation = 67
# Fitness    = -3.358185372267101
# Change     = 0.00378767633357624
#
#
# Generation = 68
# Fitness    = -3.3521646236092866
# Change     = 0.006020748657814323
#
#
# Generation = 69
# Fitness    = -3.3475888106582383
# Change     = 0.004575812951048253
#
#
# Generation = 70
# Fitness    = -3.3452212823020466
# Change     = 0.002367528356191695
#
#
# Generation = 71
# Fitness    = -3.3427249899682034
# Change     = 0.0024962923338431864
#
#
# Generation = 72
# Fitness    = -3.3379200668357756
# Change     = 0.004804923132427863
#
#
# Generation = 73
# Fitness    = -3.328968855789223
# Change     = 0.008951211046552388
#
#
# Generation = 74
# Fitness    = -3.3273982386149883
# Change     = 0.0015706171742349007
#
#
# Generation = 75
# Fitness    = -3.3248910658631057
# Change     = 0.0025071727518826137
#
#
# Generation = 76
# Fitness    = -3.323798586460327
# Change     = 0.0010924794027786788
#
#
# Generation = 77
# Fitness    = -3.3209659650169
# Change     = 0.002832621443427108
#
#
# Generation = 78
# Fitness    = -3.3175770994276896
# Change     = 0.003388865589210255
#
#
# Generation = 79
# Fitness    = -3.311238904258718
# Change     = 0.006338195168971605
#
#
# Generation = 80
# Fitness    = -3.305579384140462
# Change     = 0.005659520118256101
#
#
# Generation = 81
# Fitness    = -3.3021865370431973
# Change     = 0.0033928470972646174
#
#
# Generation = 82
# Fitness    = -3.300767724823796
# Change     = 0.001418812219401211
#
#
# Generation = 83
# Fitness    = -3.2991433140251845
# Change     = 0.0016244107986116418
#
#
# Generation = 84
# Fitness    = -3.296448479714342
# Change     = 0.0026948343108426087
#
#
# Generation = 85
# Fitness    = -3.2949923042134905
# Change     = 0.0014561755008513089
#
#
# Generation = 86
# Fitness    = -3.2901187091846213
# Change     = 0.004873595028869193
#
#
# Generation = 87
# Fitness    = -3.286247865752415
# Change     = 0.003870843432206339
#
#
# Generation = 88
# Fitness    = -3.2825350783851728
# Change     = 0.003712787367242232
#
#
# Generation = 89
# Fitness    = -3.281526826740732
# Change     = 0.0010082516444409606
#
#
# Generation = 90
# Fitness    = -3.2813374529816244
# Change     = 0.00018937375910743626
#
#
# Generation = 91
# Fitness    = -3.278672078262129
# Change     = 0.0026653747194953503
#
#
# Generation = 92
# Fitness    = -3.272602307801332
# Change     = 0.0060697704607970415
#
#
# Generation = 93
# Fitness    = -3.2696145931874954
# Change     = 0.002987714613836623
#
#
# Generation = 94
# Fitness    = -3.263217203414679
# Change     = 0.006397389772816453
#
#
# Generation = 95
# Fitness    = -3.2609929529704647
# Change     = 0.0022242504442142597
#
#
# Generation = 96
# Fitness    = -3.2600453599459898
# Change     = 0.0009475930244748909
#
#
# Generation = 97
# Fitness    = -3.250927814676366
# Change     = 0.009117545269623939
#
#
# Generation = 98
# Fitness    = -3.2487751076975893
# Change     = 0.002152706978776564
#
#
# Generation = 99
# Fitness    = -3.2476717122637737
# Change     = 0.001103395433815546
#
#
# Generation = 100
# Fitness    = -3.2433570910386464
# Change     = 0.004314621225127269
#
#
# Generation = 101
# Fitness    = -3.2433570910386464
# Change     = 0.0
#
#
# Generation = 102
# Fitness    = -3.2417941621188766
# Change     = 0.0015629289197698348
#
#
# Generation = 103
# Fitness    = -3.2404972114672135
# Change     = 0.0012969506516631313
#
#
# Generation = 104
# Fitness    = -3.2330676212219482
# Change     = 0.0074295902452652385
#
#
# Generation = 105
# Fitness    = -3.2317355739179376
# Change     = 0.0013320473040105973
#
#
# Generation = 106
# Fitness    = -3.225536795147878
# Change     = 0.0061987787700594765
#
#
# Generation = 107
# Fitness    = -3.220832120905167
# Change     = 0.00470467424271126
#
#
# Generation = 108
# Fitness    = -3.2175192729674227
# Change     = 0.0033128479377442233
#
#
# Generation = 109
# Fitness    = -3.213493802536938
# Change     = 0.004025470430484734
#
#
# Generation = 110
# Fitness    = -3.211437573590562
# Change     = 0.0020562289463761374
#
#
# Generation = 111
# Fitness    = -3.2042579927968475
# Change     = 0.00717958079371428
#
#
# Generation = 112
# Fitness    = -3.2012339240430348
# Change     = 0.003024068753812781
#
#
# Generation = 113
# Fitness    = -3.200687246022188
# Change     = 0.0005466780208469579
#
#
# Generation = 114
# Fitness    = -3.1996406682976755
# Change     = 0.001046577724512332
#
#
# Generation = 115
# Fitness    = -3.1985540307805946
# Change     = 0.001086637517080824
#
#
# Generation = 116
# Fitness    = -3.1954030620449587
# Change     = 0.0031509687356359173
#
#
# Generation = 117
# Fitness    = -3.1951010255574026
# Change     = 0.0003020364875561121
#
#
# Generation = 118
# Fitness    = -3.191165600531454
# Change     = 0.003935425025948458
#
#
# Generation = 119
# Fitness    = -3.1886785496903185
# Change     = 0.0024870508411356518
#
#
# Generation = 120
# Fitness    = -3.1868031686837996
# Change     = 0.0018753810065188503
#
#
# Generation = 121
# Fitness    = -3.1832501078460655
# Change     = 0.003553060837734101
#
#
# Generation = 122
# Fitness    = -3.180490375960795
# Change     = 0.0027597318852703445
#
#
# Generation = 123
# Fitness    = -3.1770086416699748
# Change     = 0.0034817342908204374
#
#
# Generation = 124
# Fitness    = -3.1751940604639755
# Change     = 0.0018145812059993105
#
#
# Generation = 125
# Fitness    = -3.1729413126471755
# Change     = 0.0022527478167999604
#
#
# Generation = 126
# Fitness    = -3.169863059394913
# Change     = 0.0030782532522626305
#
#
# Generation = 127
# Fitness    = -3.165348333366643
# Change     = 0.004514726028269855
#
#
# Generation = 128
# Fitness    = -3.163321677023373
# Change     = 0.002026656343269817
#
#
# Generation = 129
# Fitness    = -3.1610637893856057
# Change     = 0.002257887637767464
#
#
# Generation = 130
# Fitness    = -3.1555677702652187
# Change     = 0.005496019120386997
#
#
# Generation = 131
# Fitness    = -3.1555677702652187
# Change     = 0.0
#
#
# Generation = 132
# Fitness    = -3.1515647382543146
# Change     = 0.004003032010904128
#
#
# Generation = 133
# Fitness    = -3.1468401835900894
# Change     = 0.004724554664225167
#
#
# Generation = 134
# Fitness    = -3.1427497004423577
# Change     = 0.004090483147731749
#
#
# Generation = 135
# Fitness    = -3.139761122426518
# Change     = 0.002988578015839849
#
#
# Generation = 136
# Fitness    = -3.1321112755707965
# Change     = 0.007649846855721343
#
#
# Generation = 137
# Fitness    = -3.127841592006752
# Change     = 0.004269683564044335
#
#
# Generation = 138
# Fitness    = -3.1259761473085477
# Change     = 0.001865444698204488
#
#
# Generation = 139
# Fitness    = -3.122687975029508
# Change     = 0.0032881722790398804
#
#
# Generation = 140
# Fitness    = -3.120926228630216
# Change     = 0.0017617463992918303
#
#
# Generation = 141
# Fitness    = -3.1188511053670966
# Change     = 0.002075123263119316
#
#
# Generation = 142
# Fitness    = -3.1164266681922776
# Change     = 0.002424437174818994
#
#
# Generation = 143
# Fitness    = -3.1140378041070793
# Change     = 0.002388864085198339
#
#
# Generation = 144
# Fitness    = -3.1125577549483703
# Change     = 0.0014800491587090292
#
#
# Generation = 145
# Fitness    = -3.1119806504536434
# Change     = 0.000577104494726921
#
#
# Generation = 146
# Fitness    = -3.110972432672999
# Change     = 0.001008217780644305
#
#
# Generation = 147
# Fitness    = -3.1099177801710884
# Change     = 0.0010546525019106134
#
#
# Generation = 148
# Fitness    = -3.108571427035618
# Change     = 0.0013463531354704905
#
#
# Generation = 149
# Fitness    = -3.103617909424487
# Change     = 0.004953517611130831
#
#
# Generation = 150
# Fitness    = -3.1020732907073034
# Change     = 0.001544618717183699
#
#
# Generation = 151
# Fitness    = -3.1009485178614082
# Change     = 0.0011247728458951833
#
#
# Generation = 152
# Fitness    = -3.094141080275477
# Change     = 0.006807437585931275
#
#
# Generation = 153
# Fitness    = -3.0868873053721395
# Change     = 0.007253774903337451
#
#
# Generation = 154
# Fitness    = -3.0861196477086192
# Change     = 0.0007676576635202714
#
#
# Generation = 155
# Fitness    = -3.0837975993823794
# Change     = 0.002322048326239834
#
#
# Generation = 156
# Fitness    = -3.0759336330593636
# Change     = 0.00786396632301578
#
#
# Generation = 157
# Fitness    = -3.07069434688974
# Change     = 0.005239286169623547
#
#
# Generation = 158
# Fitness    = -3.0677424801147084
# Change     = 0.002951866775031675
#
#
# Generation = 159
# Fitness    = -3.0655565706817987
# Change     = 0.0021859094329097495
#
#
# Generation = 160
# Fitness    = -3.0635611504980798
# Change     = 0.001995420183718899
#
#
# Generation = 161
# Fitness    = -3.0601520249211687
# Change     = 0.0034091255769110873
#
#
# Generation = 162
# Fitness    = -3.05682553709
# Change     = 0.003326487831168734
#
#
# Generation = 163
# Fitness    = -3.052557058802785
# Change     = 0.004268478287214883
#
#
# Generation = 164
# Fitness    = -3.052557058802785
# Change     = 0.0
#
#
# Generation = 165
# Fitness    = -3.0501813264896316
# Change     = 0.002375732313153467
#
#
# Generation = 166
# Fitness    = -3.049870717699686
# Change     = 0.0003106087899453769
#
#
# Generation = 167
# Fitness    = -3.0450140952016307
# Change     = 0.004856622498055518
#
#
# Generation = 168
# Fitness    = -3.041156860230206
# Change     = 0.003857234971424539
#
#
# Generation = 169
# Fitness    = -3.037118773689436
# Change     = 0.004038086540770092
#
#
# Generation = 170
# Fitness    = -3.0346563468612158
# Change     = 0.0024624268282202877
#
#
# Generation = 171
# Fitness    = -3.034143837180104
# Change     = 0.0005125096811116059
#
#
# Generation = 172
# Fitness    = -3.032660871192035
# Change     = 0.0014829659880692958
#
#
# Generation = 173
# Fitness    = -3.0271709367462836
# Change     = 0.005489934445751299
#
#
# Generation = 174
# Fitness    = -3.026519042408919
# Change     = 0.0006518943373645669
#
#
# Generation = 175
# Fitness    = -3.0253189999230097
# Change     = 0.001200042485909325
#
#
# Generation = 176
# Fitness    = -3.023554294673961
# Change     = 0.0017647052490485926
#
#
# Generation = 177
# Fitness    = -3.0219190016207746
# Change     = 0.0016352930531864374
#
#
# Generation = 178
# Fitness    = -3.0184176844945245
# Change     = 0.0035013171262501253
#
#
# Generation = 179
# Fitness    = -3.01209945201522
# Change     = 0.00631823247930452
#
#
# Generation = 180
# Fitness    = -3.010889417735787
# Change     = 0.0012100342794330032
#
#
# Generation = 181
# Fitness    = -3.007744815438271
# Change     = 0.003144602297516119
#
#
# Generation = 182
# Fitness    = -3.005295592528996
# Change     = 0.0024492229092749618
#
#
# Generation = 183
# Fitness    = -3.001466775416914
# Change     = 0.003828817112081939
#
#
# Generation = 184
# Fitness    = -2.998212829845854
# Change     = 0.0032539455710600684
#
#
# Generation = 185
# Fitness    = -2.9942490175421272
# Change     = 0.003963812303726666
#
#
# Generation = 186
# Fitness    = -2.9895951556912332
# Change     = 0.004653861850894003
#
#
# Generation = 187
# Fitness    = -2.9867336192266247
# Change     = 0.002861536464608516
#
#
# Generation = 188
# Fitness    = -2.9850974318308006
# Change     = 0.0016361873958241624
#
#
# Generation = 189
# Fitness    = -2.983526305029268
# Change     = 0.0015711268015325963
#
#
# Generation = 190
# Fitness    = -2.980996054131688
# Change     = 0.0025302508975801885
#
#
# Generation = 191
# Fitness    = -2.975136638341673
# Change     = 0.005859415790014921
#
#
# Generation = 192
# Fitness    = -2.9719935148554484
# Change     = 0.003143123486224475
#
#
# Generation = 193
# Fitness    = -2.971377744740429
# Change     = 0.0006157701150195649
#
#
# Generation = 194
# Fitness    = -2.969300703602172
# Change     = 0.0020770411382566856
#
#
# Generation = 195
# Fitness    = -2.96367913799988
# Change     = 0.005621565602292211
#
#
# Generation = 196
# Fitness    = -2.9629282915624384
# Change     = 0.0007508464374414991
#
#
# Generation = 197
# Fitness    = -2.961246924174396
# Change     = 0.0016813673880422542
#
#
# Generation = 198
# Fitness    = -2.9571812784842857
# Change     = 0.004065645690110475
#
#
# Generation = 199
# Fitness    = -2.9557680237697044
# Change     = 0.0014132547145813135
#
#
# Generation = 200
# Fitness    = -2.955205713731449
# Change     = 0.0005623100382554647
#
#
# Generation = 201
# Fitness    = -2.953049549043952
# Change     = 0.0021561646874967977
#
#
# Generation = 202
# Fitness    = -2.9486446088490927
# Change     = 0.004404940194859375
#
#
# Generation = 203
# Fitness    = -2.9437507843523094
# Change     = 0.004893824496783328
#
#
# Generation = 204
# Fitness    = -2.9425194392880107
# Change     = 0.0012313450642986723
#
#
# Generation = 205
# Fitness    = -2.940469475790029
# Change     = 0.0020499634979818104
#
#
# Generation = 206
# Fitness    = -2.9384732559639475
# Change     = 0.0019962198260814468
#
#
# Generation = 207
# Fitness    = -2.9376303330549565
# Change     = 0.0008429229089910173
#
#
# Generation = 208
# Fitness    = -2.934910357926372
# Change     = 0.002719975128584462
#
#
# Generation = 209
# Fitness    = -2.934136523695651
# Change     = 0.0007738342307210822
#
#
# Generation = 210
# Fitness    = -2.93202842370166
# Change     = 0.002108099993991086
#
#
# Generation = 211
# Fitness    = -2.9292986174539855
# Change     = 0.0027298062476743823
#
#
# Generation = 212
# Fitness    = -2.9267208709442976
# Change     = 0.002577746509687895
#
#
# Generation = 213
# Fitness    = -2.922690620876309
# Change     = 0.004030250067988739
#
#
# Generation = 214
# Fitness    = -2.922690620876309
# Change     = 0.0
#
#
# Generation = 215
# Fitness    = -2.921112034297759
# Change     = 0.0015785865785500341
#
#
# Generation = 216
# Fitness    = -2.9180992650079713
# Change     = 0.0030127692897874425
#
#
# Generation = 217
# Fitness    = -2.9174428969804596
# Change     = 0.0006563680275117889
#
#
# Generation = 218
# Fitness    = -2.9167911199186687
# Change     = 0.0006517770617908702
#
#
# Generation = 219
# Fitness    = -2.9145441062755153
# Change     = 0.002247013643153384
#
#
# Generation = 220
# Fitness    = -2.9138273469893763
# Change     = 0.0007167592861390126
#
#
# Generation = 221
# Fitness    = -2.9117188140669983
# Change     = 0.0021085329223780036
#
#
# Generation = 222
# Fitness    = -2.9109805274418905
# Change     = 0.0007382866251077758
#
#
# Generation = 223
# Fitness    = -2.9093677043623476
# Change     = 0.0016128230795429133
#
#
# Generation = 224
# Fitness    = -2.9086623941114707
# Change     = 0.0007053102508769449
#
#
# Generation = 225
# Fitness    = -2.906865065777048
# Change     = 0.0017973283344225877
#
#
# Generation = 226
# Fitness    = -2.906421968867829
# Change     = 0.0004430969092190651
#
#
# Generation = 227
# Fitness    = -2.9049650532146267
# Change     = 0.0014569156532022731
#
#
# Generation = 228
# Fitness    = -2.9035495896725383
# Change     = 0.0014154635420884354
#
#
# Generation = 229
# Fitness    = -2.9017298119151436
# Change     = 0.001819777757394725
#
#
# Generation = 230
# Fitness    = -2.8999230099605113
# Change     = 0.0018068019546322311
#
#
# Generation = 231
# Fitness    = -2.8949446764890943
# Change     = 0.0049783334714170735
#
#
# Generation = 232
# Fitness    = -2.8931643049208624
# Change     = 0.0017803715682318533
#
#
# Generation = 233
# Fitness    = -2.891685633068814
# Change     = 0.0014786718520483078
#
#
# Generation = 234
# Fitness    = -2.8908946836019545
# Change     = 0.0007909494668596473
#
#
# Generation = 235
# Fitness    = -2.889310006296924
# Change     = 0.0015846773050305352
#
#
# Generation = 236
# Fitness    = -2.8885046469299374
# Change     = 0.0008053593669865577
#
#
# Generation = 237
# Fitness    = -2.885546589905506
# Change     = 0.0029580570244314153
#
#
# Generation = 238
# Fitness    = -2.883906237121516
# Change     = 0.0016403527839901066
#
#
# Generation = 239
# Fitness    = -2.880806383302059
# Change     = 0.003099853819456655
#
#
# Generation = 240
# Fitness    = -2.8787953832285407
# Change     = 0.0020110000735185096
#
#
# Generation = 241
# Fitness    = -2.878262545896437
# Change     = 0.0005328373321038526
#
#
# Generation = 242
# Fitness    = -2.875653389431521
# Change     = 0.002609156464915774
#
#
# Generation = 243
# Fitness    = -2.8742129814207593
# Change     = 0.001440408010761729
#
#
# Generation = 244
# Fitness    = -2.8725573082065394
# Change     = 0.0016556732142198882
#
#
# Generation = 245
# Fitness    = -2.871139236907208
# Change     = 0.0014180712993314692
#
#
# Generation = 246
# Fitness    = -2.8668652638745846
# Change     = 0.004273973032623335
#
#
# Generation = 247
# Fitness    = -2.8649298565156265
# Change     = 0.001935407358958141
#
#
# Generation = 248
# Fitness    = -2.863744322094072
# Change     = 0.0011855344215545571
#
#
# Generation = 249
# Fitness    = -2.8633372024999484
# Change     = 0.0004071195941235395
#
#
# Generation = 250
# Fitness    = -2.8616767023006098
# Change     = 0.0016605001993386104
#
#
# Generation = 251
# Fitness    = -2.8611078437742345
# Change     = 0.0005688585263752266
#
#
# Generation = 252
# Fitness    = -2.8603702053292275
# Change     = 0.0007376384450070717
#
#
# Generation = 253
# Fitness    = -2.858990287138555
# Change     = 0.0013799181906724023
#
#
# Generation = 254
# Fitness    = -2.8565638844169583
# Change     = 0.0024264027215967765
#
#
# Generation = 255
# Fitness    = -2.8556328761325465
# Change     = 0.0009310082844118384
#
#
# Generation = 256
# Fitness    = -2.8547504495944613
# Change     = 0.0008824265380851237
#
#
# Generation = 257
# Fitness    = -2.8523225428753043
# Change     = 0.002427906719157047
#
#
# Generation = 258
# Fitness    = -2.8480891656136054
# Change     = 0.004233377261698923
#
#
# Generation = 259
# Fitness    = -2.846817525353923
# Change     = 0.001271640259682183
#
#
# Generation = 260
# Fitness    = -2.846127674822298
# Change     = 0.0006898505316250692
#
#
# Generation = 261
# Fitness    = -2.844620614746421
# Change     = 0.001507060075877309
#
#
# Generation = 262
# Fitness    = -2.8433915267317547
# Change     = 0.0012290880146661465
#
#
# Generation = 263
# Fitness    = -2.84106088181138
# Change     = 0.0023306449203746027
#
#
# Generation = 264
# Fitness    = -2.839614680126634
# Change     = 0.0014462016847458514
#
#
# Generation = 265
# Fitness    = -2.8386392703652694
# Change     = 0.0009754097613647872
#
#
# Generation = 266
# Fitness    = -2.8379994865474774
# Change     = 0.0006397838177920612
#
#
# Generation = 267
# Fitness    = -2.83727641250535
# Change     = 0.0007230740421273474
#
#
# Generation = 268
# Fitness    = -2.8363662015158213
# Change     = 0.0009102109895287036
#
#
# Generation = 269
# Fitness    = -2.8315738483988206
# Change     = 0.004792353117000658
#
#
# Generation = 270
# Fitness    = -2.8298668317134728
# Change     = 0.0017070166853478952
#
#
# Generation = 271
# Fitness    = -2.8269742549216783
# Change     = 0.0028925767917944434
#
#
# Generation = 272
# Fitness    = -2.8253487381285427
# Change     = 0.0016255167931356063
#
#
# Generation = 273
# Fitness    = -2.8240979044703862
# Change     = 0.0012508336581564805
#
#
# Generation = 274
# Fitness    = -2.8231389064070305
# Change     = 0.0009589980633557538
#
#
# Generation = 275
# Fitness    = -2.819435168824428
# Change     = 0.00370373758260234
#
#
# Generation = 276
# Fitness    = -2.817362026113138
# Change     = 0.00207314271129011
#
#
# Generation = 277
# Fitness    = -2.815006816618881
# Change     = 0.00235520949425716
#
#
# Generation = 278
# Fitness    = -2.8136423689406196
# Change     = 0.0013644476782612713
#
#
# Generation = 279
# Fitness    = -2.810275034883777
# Change     = 0.0033673340568425303
#
#
# Generation = 280
# Fitness    = -2.8093255901128873
# Change     = 0.0009494447708897624
#
#
# Generation = 281
# Fitness    = -2.8077928007738144
# Change     = 0.0015327893390728597
#
#
# Generation = 282
# Fitness    = -2.8054843872885695
# Change     = 0.002308413485244909
#
#
# Generation = 283
# Fitness    = -2.8048081362651756
# Change     = 0.00067625102339397
#
#
# Generation = 284
# Fitness    = -2.8020353949735157
# Change     = 0.0027727412916598304
#
#
# Generation = 285
# Fitness    = -2.797828927574183
# Change     = 0.004206467399332947
#
#
# Generation = 286
# Fitness    = -2.7973419880464077
# Change     = 0.00048693952777512095
#
#
# Generation = 287
# Fitness    = -2.795439563601767
# Change     = 0.0019024244446406158
#
#
# Generation = 288
# Fitness    = -2.7949057527004846
# Change     = 0.000533810901282461
#
#
# Generation = 289
# Fitness    = -2.7923255063942034
# Change     = 0.0025802463062811754
#
#
# Generation = 290
# Fitness    = -2.7901849081590053
# Change     = 0.002140598235198077
#
#
# Generation = 291
# Fitness    = -2.7895823570497886
# Change     = 0.000602551109216698
#
#
# Generation = 292
# Fitness    = -2.7880023843524797
# Change     = 0.0015799726973089179
#
#
# Generation = 293
# Fitness    = -2.786312885001304
# Change     = 0.0016894993511757939
#
#
# Generation = 294
# Fitness    = -2.7837804461057067
# Change     = 0.0025324388955971777
#
#
# Generation = 295
# Fitness    = -2.7828230381354597
# Change     = 0.0009574079702470151
#
#
# Generation = 296
# Fitness    = -2.781857783992708
# Change     = 0.0009652541427516148
#
#
# Generation = 297
# Fitness    = -2.7790048495623694
# Change     = 0.0028529344303387383
#
#
# Generation = 298
# Fitness    = -2.778437250565929
# Change     = 0.0005675989964402106
#
#
# Generation = 299
# Fitness    = -2.7756590622876596
# Change     = 0.002778188278269589
#
#
# Generation = 300
# Fitness    = -2.7749638177496987
# Change     = 0.0006952445379608818
#
#
# Generation = 301
# Fitness    = -2.773859320504757
# Change     = 0.0011044972449418822
#
#
# Generation = 302
# Fitness    = -2.771563137346407
# Change     = 0.002296183158349674
#
#
# Generation = 303
# Fitness    = -2.769002628029313
# Change     = 0.002560509317094173
#
#
# Generation = 304
# Fitness    = -2.7687780964384614
# Change     = 0.00022453159085156216
#
#
# Generation = 305
# Fitness    = -2.7674287371983266
# Change     = 0.0013493592401347954
#
#
# Generation = 306
# Fitness    = -2.766552898760116
# Change     = 0.0008758384382105966
#
#
# Generation = 307
# Fitness    = -2.765348157540645
# Change     = 0.0012047412194711171
#
#
# Generation = 308
# Fitness    = -2.764100193009867
# Change     = 0.0012479645307776899
#
#
# Generation = 309
# Fitness    = -2.7631782656112978
# Change     = 0.0009219273985694443
#
#
# Generation = 310
# Fitness    = -2.761912407125541
# Change     = 0.0012658584857567767
#
#
# Generation = 311
# Fitness    = -2.7611457101287753
# Change     = 0.0007666969967656811
#
#
# Generation = 312
# Fitness    = -2.757450221048038
# Change     = 0.0036954890807372465
#
#
# Generation = 313
# Fitness    = -2.7565500988603215
# Change     = 0.0009001221877165122
#
#
# Generation = 314
# Fitness    = -2.7553045465757733
# Change     = 0.001245552284548257
#
#
# Generation = 315
# Fitness    = -2.753412780856929
# Change     = 0.0018917657188444181
#
#
# Generation = 316
# Fitness    = -2.752324390862679
# Change     = 0.001088389994249983
#
#
# Generation = 317
# Fitness    = -2.751286976587422
# Change     = 0.0010374142752569426
#
#
# Generation = 318
# Fitness    = -2.7490341432076564
# Change     = 0.002252833379765562
#
#
# Generation = 319
# Fitness    = -2.7480581778950715
# Change     = 0.0009759653125849255
#
#
# Generation = 320
# Fitness    = -2.746276149227393
# Change     = 0.0017820286676784036
#
#
# Generation = 321
# Fitness    = -2.7458641166607647
# Change     = 0.00041203256662836196
#
#
# Generation = 322
# Fitness    = -2.7450429098980087
# Change     = 0.0008212067627559883
#
#
# Generation = 323
# Fitness    = -2.7450429098980087
# Change     = 0.0
#
#
# Generation = 324
# Fitness    = -2.744396604696718
# Change     = 0.000646305201290609
#
#
# Generation = 325
# Fitness    = -2.7428649747639327
# Change     = 0.0015316299327854388
#
#
# Generation = 326
# Fitness    = -2.741888260859657
# Change     = 0.0009767139042757833
#
#
# Generation = 327
# Fitness    = -2.740819219940265
# Change     = 0.0010690409193920836
#
#
# Generation = 328
# Fitness    = -2.740778762603552
# Change     = 4.0457336712762526e-05
#
#
# Generation = 329
# Fitness    = -2.7394664532778186
# Change     = 0.0013123093257334517
#
#
# Generation = 330
# Fitness    = -2.738284811610147
# Change     = 0.0011816416676717623
#
#
# Generation = 331
# Fitness    = -2.736460938818663
# Change     = 0.0018238727914838826
#
#
# Generation = 332
# Fitness    = -2.7360279881097456
# Change     = 0.00043295070891735676
#
#
# Generation = 333
# Fitness    = -2.734109696945517
# Change     = 0.0019182911642285916
#
#
# Generation = 334
# Fitness    = -2.7310105360095807
# Change     = 0.003099160935936318
#
#
# Generation = 335
# Fitness    = -2.729427067463191
# Change     = 0.001583468546389799
#
#
# Generation = 336
# Fitness    = -2.7284304567225193
# Change     = 0.0009966107406715885
#
#
# Generation = 337
# Fitness    = -2.7273054681680913
# Change     = 0.001124988554427997
#
#
# Generation = 338
# Fitness    = -2.726305915058727
# Change     = 0.0009995531093642818
#
#
# Generation = 339
# Fitness    = -2.7225157344163256
# Change     = 0.0037901806424014417
#
#
# Generation = 340
# Fitness    = -2.721941659403595
# Change     = 0.0005740750127305461
#
#
# Generation = 341
# Fitness    = -2.720967707624891
# Change     = 0.0009739517787039631
#
#
# Generation = 342
# Fitness    = -2.7196074303779287
# Change     = 0.0013602772469623048
#
#
# Generation = 343
# Fitness    = -2.7186162715568156
# Change     = 0.000991158821113114
#
#
# Generation = 344
# Fitness    = -2.7155260658804106
# Change     = 0.0030902056764050556
#
#
# Generation = 345
# Fitness    = -2.7145391495565847
# Change     = 0.0009869163238258594
#
#
# Generation = 346
# Fitness    = -2.7121262904676464
# Change     = 0.0024128590889382906
#
#
# Generation = 347
# Fitness    = -2.711730173073613
# Change     = 0.00039611739403344615
#
#
# Generation = 348
# Fitness    = -2.710033509183012
# Change     = 0.00169666389060108
#
#
# Generation = 349
# Fitness    = -2.7098679147988873
# Change     = 0.00016559438412455663
#
#
# Generation = 350
# Fitness    = -2.708389312438033
# Change     = 0.0014786023608541754
#
#
# Generation = 351
# Fitness    = -2.707014870287746
# Change     = 0.0013744421502872584
#
#
# Generation = 352
# Fitness    = -2.7062881316740253
# Change     = 0.0007267386137206344
#
#
# Generation = 353
# Fitness    = -2.7056420981499767
# Change     = 0.0006460335240485726
#
#
# Generation = 354
# Fitness    = -2.70475735890201
# Change     = 0.0008847392479665039
#
#
# Generation = 355
# Fitness    = -2.7032984737450088
# Change     = 0.0014588851570014327
#
#
# Generation = 356
# Fitness    = -2.702858596958425
# Change     = 0.0004398767865838593
#
#
# Generation = 357
# Fitness    = -2.699283867119817
# Change     = 0.0035747298386077375
#
#
# Generation = 358
# Fitness    = -2.698351041954353
# Change     = 0.0009328251654641129
#
#
# Generation = 359
# Fitness    = -2.6976151906362706
# Change     = 0.0007358513180824033
#
#
# Generation = 360
# Fitness    = -2.6960800834222094
# Change     = 0.0015351072140612487
#
#
# Generation = 361
# Fitness    = -2.6949452150052124
# Change     = 0.001134868416996948
#
#
# Generation = 362
# Fitness    = -2.6943758965468483
# Change     = 0.0005693184583641653
#
#
# Generation = 363
# Fitness    = -2.6910887551216622
# Change     = 0.0032871414251860465
#
#
# Generation = 364
# Fitness    = -2.6906636800307266
# Change     = 0.00042507509093558937
#
#
# Generation = 365
# Fitness    = -2.6891827850670755
# Change     = 0.0014808949636511137
#
#
# Generation = 366
# Fitness    = -2.6871603448137678
# Change     = 0.002022440253307778
#
#
# Generation = 367
# Fitness    = -2.686023242779765
# Change     = 0.001137102034002968
#
#
# Generation = 368
# Fitness    = -2.6833914181133802
# Change     = 0.0026318246663845635
#
#
# Generation = 369
# Fitness    = -2.6811212469333747
# Change     = 0.002270171180005498
#
#
# Generation = 370
# Fitness    = -2.6800712301745495
# Change     = 0.0010500167588252118
#
#
# Generation = 371
# Fitness    = -2.6785897289727267
# Change     = 0.001481501201822777
#
#
# Generation = 372
# Fitness    = -2.6780972064416453
# Change     = 0.0004925225310814518
#
#
# Generation = 373
# Fitness    = -2.6775676542615336
# Change     = 0.0005295521801116365
#
#
# Generation = 374
# Fitness    = -2.675724033276289
# Change     = 0.0018436209852445984
#
#
# Generation = 375
# Fitness    = -2.674926962074659
# Change     = 0.000797071201629862
#
#
# Generation = 376
# Fitness    = -2.67420244555817
# Change     = 0.0007245165164890821
#
#
# Generation = 377
# Fitness    = -2.672472450613825
# Change     = 0.0017299949443452256
#
#
# Generation = 378
# Fitness    = -2.6707537037525344
# Change     = 0.0017187468612904766
#
#
# Generation = 379
# Fitness    = -2.670109372574024
# Change     = 0.0006443311785102601
#
#
# Generation = 380
# Fitness    = -2.668402908745771
# Change     = 0.0017064638282531241
#
#
# Generation = 381
# Fitness    = -2.6662082912002476
# Change     = 0.002194617545523414
#
#
# Generation = 382
# Fitness    = -2.66495195306392
# Change     = 0.0012563381363275283
#
#
# Generation = 383
# Fitness    = -2.6637023990703437
# Change     = 0.0012495539935764022
#
#
# Generation = 384
# Fitness    = -2.662972168210247
# Change     = 0.0007302308600967145
# Generation = 385
# Fitness    = -2.659425452339418
# Change     = 0.003546715870828887
#
#
# Generation = 386
# Fitness    = -2.658974206380672
# Change     = 0.0004512459587462381
#
#
# Generation = 387
# Fitness    = -2.65833184640561
# Change     = 0.0006423599750617903
#
#
# Generation = 388
# Fitness    = -2.657715207896073
# Change     = 0.0006166385095371929
#
#
# Generation = 389
# Fitness    = -2.655975913700711
# Change     = 0.0017392941953620067
#
#
# Generation = 390
# Fitness    = -2.655975913700711
# Change     = 0.0
#
#
# Generation = 391
# Fitness    = -2.654989673627185
# Change     = 0.0009862400735256571
#
#
# Generation = 392
# Fitness    = -2.654862398500928
# Change     = 0.00012727512625732018
#
#
# Generation = 393
# Fitness    = -2.652128979361426
# Change     = 0.002733419139501869
#
#
# Generation = 394
# Fitness    = -2.650705294310938
# Change     = 0.001423685050487844
#
#
# Generation = 395
# Fitness    = -2.6490411750827834
# Change     = 0.0016641192281547923
#
#
# Generation = 396
# Fitness    = -2.647928332787551
# Change     = 0.0011128422952322303
#
#
# Generation = 397
# Fitness    = -2.6475011976335368
# Change     = 0.00042713515401437974
#
#
# Generation = 398
# Fitness    = -2.646741713468792
# Change     = 0.0007594841647446948
#
#
# Generation = 399
# Fitness    = -2.6453764463255425
# Change     = 0.0013652671432495822
#
#
# Generation = 400
# Fitness    = -2.6447361515515686
# Change     = 0.0006402947739738707
#
#
# Generation = 401
# Fitness    = -2.6438197094580382
# Change     = 0.0009164420935303674
#
#
# Generation = 402
# Fitness    = -2.6428574593186904
# Change     = 0.0009622501393478089
#
#
# Generation = 403
# Fitness    = -2.6410716479749077
# Change     = 0.0017858113437827505
#
#
# Generation = 404
# Fitness    = -2.6410716479749077
# Change     = 0.0
#
#
# Generation = 405
# Fitness    = -2.639963610955794
# Change     = 0.0011080370191138833
#
#
# Generation = 406
# Fitness    = -2.6391887973038894
# Change     = 0.0007748136519043491
#
#
# Generation = 407
# Fitness    = -2.636626926599823
# Change     = 0.00256187070406666
#
#
# Generation = 408
# Fitness    = -2.6352331482293203
# Change     = 0.0013937783705024742
#
#
# Generation = 409
# Fitness    = -2.635081477887453
# Change     = 0.00015167034186713835
#
#
# Generation = 410
# Fitness    = -2.634775896881775
# Change     = 0.0003055810056782349
#
#
# Generation = 411
# Fitness    = -2.6329303260683856
# Change     = 0.001845570813389319
#
#
# Generation = 412
# Fitness    = -2.630514107817986
# Change     = 0.0024162182503997265
#
#
# Generation = 413
# Fitness    = -2.6295133687612955
# Change     = 0.0010007390566904029
#
#
# Generation = 414
# Fitness    = -2.6278980351667487
# Change     = 0.0016153335945467973
#
#
# Generation = 415
# Fitness    = -2.6278980351667487
# Change     = 0.0
#
#
# Generation = 416
# Fitness    = -2.627217368140463
# Change     = 0.000680667026285775
#
#
# Generation = 417
# Fitness    = -2.6260064129679423
# Change     = 0.001210955172520567
#
#
# Generation = 418
# Fitness    = -2.6257711080807544
# Change     = 0.00023530488718792597
#
#
# Generation = 419
# Fitness    = -2.625014033994098
# Change     = 0.000757074086656484
#
#
# Generation = 420
# Fitness    = -2.623050074663035
# Change     = 0.00196395933106297
#
#
# Generation = 421
# Fitness    = -2.6214078760448842
# Change     = 0.0016421986181507364
#
#
# Generation = 422
# Fitness    = -2.6181203712193506
# Change     = 0.003287504825533638
#
#
# Generation = 423
# Fitness    = -2.6173151766555116
# Change     = 0.0008051945638389846
#
#
# Generation = 424
# Fitness    = -2.6172299610682126
# Change     = 8.521558729901457e-05
#
#
# Generation = 425
# Fitness    = -2.615724570000116
# Change     = 0.00150539106809644
#
#
# Generation = 426
# Fitness    = -2.6150527773554
# Change     = 0.0006717926447161737
#
#
# Generation = 427
# Fitness    = -2.6147934733931386
# Change     = 0.0002593039622613702
#
#
# Generation = 428
# Fitness    = -2.6137634427782293
# Change     = 0.0010300306149093608
#
#
# Generation = 429
# Fitness    = -2.6117403908191443
# Change     = 0.0020230519590849205
#
#
# Generation = 430
# Fitness    = -2.61060337154648
# Change     = 0.001137019272664297
#
#
# Generation = 431
# Fitness    = -2.6087863795818422
# Change     = 0.001816991964637804
#
#
# Generation = 432
# Fitness    = -2.608552953927074
# Change     = 0.0002334256547680269
#
#
# Generation = 433
# Fitness    = -2.6061798910438965
# Change     = 0.0023730628831777345
#
#
# Generation = 434
# Fitness    = -2.603694093092995
# Change     = 0.002485797950901425
#
#
# Generation = 435
# Fitness    = -2.6030107289043207
# Change     = 0.000683364188674318
#
#
# Generation = 436
# Fitness    = -2.601124640233654
# Change     = 0.0018860886706666413
#
#
# Generation = 437
# Fitness    = -2.6000718850750317
# Change     = 0.0010527551586223538
#
#
# Generation = 438
# Fitness    = -2.5995045554890472
# Change     = 0.0005673295859844885
#
#
# Generation = 439
# Fitness    = -2.5978833011565956
# Change     = 0.0016212543324516382
#
#
# Generation = 440
# Fitness    = -2.5963874576963795
# Change     = 0.0014958434602161397
#
#
# Generation = 441
# Fitness    = -2.595212110371434
# Change     = 0.0011753473249456192
#
#
# Generation = 442
# Fitness    = -2.5942215668752473
# Change     = 0.0009905434961865467
#
#
# Generation = 443
# Fitness    = -2.593408983493388
# Change     = 0.0008125833818590777
#
#
# Generation = 444
# Fitness    = -2.5932452652033287
# Change     = 0.00016371829005956684
#
#
# Generation = 445
# Fitness    = -2.5927049285828625
# Change     = 0.000540336620466153
#
#
# Generation = 446
# Fitness    = -2.5913535966526573
# Change     = 0.0013513319302052018
#
#
# Generation = 447
# Fitness    = -2.59019246118593
# Change     = 0.0011611354667273588
#
#
# Generation = 448
# Fitness    = -2.589370728364881
# Change     = 0.000821732821048915
#
#
# Generation = 449
# Fitness    = -2.5888325541070683
# Change     = 0.0005381742578127735
#
#
# Generation = 450
# Fitness    = -2.588141784022452
# Change     = 0.0006907700846161546
#
#
# Generation = 451
# Fitness    = -2.587425722811336
# Change     = 0.0007160612111158926
#
#
# Generation = 452
# Fitness    = -2.586787871167312
# Change     = 0.000637851644024412
#
#
# Generation = 453
# Fitness    = -2.5853047439804144
# Change     = 0.0014831271868973595
#
#
# Generation = 454
# Fitness    = -2.5844323362824717
# Change     = 0.0008724076979427231
#
#
# Generation = 455
# Fitness    = -2.5837306549935324
# Change     = 0.0007016812889393265
#
#
# Generation = 456
# Fitness    = -2.583148085442269
# Change     = 0.0005825695512635676
#
#
# Generation = 457
# Fitness    = -2.582851499913022
# Change     = 0.00029658552924693993
#
#
# Generation = 458
# Fitness    = -2.5816621357835166
# Change     = 0.0011893641295053214
#
#
# Generation = 459
# Fitness    = -2.5794463894853275
# Change     = 0.002215746298189103
#
#
# Generation = 460
# Fitness    = -2.578004622021086
# Change     = 0.0014417674642412948
#
#
# Generation = 461
# Fitness    = -2.578004622021086
# Change     = 0.0
#
#
# Generation = 462
# Fitness    = -2.577283124817423
# Change     = 0.0007214972036631018
#
#
# Generation = 463
# Fitness    = -2.576061318061995
# Change     = 0.0012218067554279344
#
#
# Generation = 464
# Fitness    = -2.576061318061995
# Change     = 0.0
#
#
# Generation = 465
# Fitness    = -2.5754028999541427
# Change     = 0.0006584181078523876
#
#
# Generation = 466
# Fitness    = -2.5744286156121308
# Change     = 0.0009742843420119662
#
#
# Generation = 467
# Fitness    = -2.5736951289017993
# Change     = 0.0007334867103314657
#
#
# Generation = 468
# Fitness    = -2.5729343285123205
# Change     = 0.0007608003894787885
#
#
# Generation = 469
# Fitness    = -2.5724590712905115
# Change     = 0.0004752572218089668
#
#
# Generation = 470
# Fitness    = -2.571945898190573
# Change     = 0.0005131730999385908
#
#
# Generation = 471
# Fitness    = -2.5711389970844842
# Change     = 0.0008069011060887199
#
#
# Generation = 472
# Fitness    = -2.5698256491376865
# Change     = 0.001313347946797716
#
#
# Generation = 473
# Fitness    = -2.567814866223769
# Change     = 0.0020107829139175415
#
#
# Generation = 474
# Fitness    = -2.5673263419878545
# Change     = 0.0004885242359145003
#
#
# Generation = 475
# Fitness    = -2.5673263419878545
# Change     = 0.0
#
#
# Generation = 476
# Fitness    = -2.566251045932948
# Change     = 0.0010752960549065271
#
#
# Generation = 477
# Fitness    = -2.564086019829507
# Change     = 0.002165026103440937
#
#
# Generation = 478
# Fitness    = -2.563520143664463
# Change     = 0.0005658761650439992
#
#
# Generation = 479
# Fitness    = -2.5633787970407997
# Change     = 0.00014134662366327433
#
#
# Generation = 480
# Fitness    = -2.562681907831816
# Change     = 0.0006968892089838086
#
#
# Generation = 481
# Fitness    = -2.5615482030828653
# Change     = 0.0011337047489505814
#
#
# Generation = 482
# Fitness    = -2.5590819572959793
# Change     = 0.0024662457868860344
#
#
# Generation = 483
# Fitness    = -2.557332703430602
# Change     = 0.001749253865377387
#
#
# Generation = 484
# Fitness    = -2.557040451671424
# Change     = 0.00029225175917790835
#
#
# Generation = 485
# Fitness    = -2.5564654733743986
# Change     = 0.0005749782970254635
#
#
# Generation = 486
# Fitness    = -2.5557505427983496
# Change     = 0.0007149305760489888
#
#
# Generation = 487
# Fitness    = -2.5550720013431674
# Change     = 0.0006785414551822022
#
#
# Generation = 488
# Fitness    = -2.554482551721197
# Change     = 0.0005894496219704948
#
#
# Generation = 489
# Fitness    = -2.5538449832720103
# Change     = 0.0006375684491866096
#
#
# Generation = 490
# Fitness    = -2.5529514437247536
# Change     = 0.0008935395472566832
#
#
# Generation = 491
# Fitness    = -2.5524322650151854
# Change     = 0.000519178709568191
#
#
# Generation = 492
# Fitness    = -2.5512613754234725
# Change     = 0.0011708895917128537
#
#
# Generation = 493
# Fitness    = -2.5503289482326226
# Change     = 0.0009324271908499604
#
#
# Generation = 494
# Fitness    = -2.549737207617925
# Change     = 0.0005917406146975779
#
#
# Generation = 495
# Fitness    = -2.549737207617925
# Change     = 0.0
#
#
# Generation = 496
# Fitness    = -2.5483409706015427
# Change     = 0.0013962370163822513
#
#
# Generation = 497
# Fitness    = -2.547724645257924
# Change     = 0.0006163253436186622
#
#
# Generation = 498
# Fitness    = -2.546785541088763
# Change     = 0.000939104169161098
#
#
# Generation = 499
# Fitness    = -2.5450697206699875
# Change     = 0.0017158204187754933
#
#
# Generation = 500
# Fitness    = -2.5446342131365047
# Change     = 0.0004355075334827596
#
#
# Generation = 501
# Fitness    = -2.543257604453624
# Change     = 0.0013766086828805868
#
#
# Generation = 502
# Fitness    = -2.542914827148916
# Change     = 0.0003427773047079974
#
#
# Generation = 503
# Fitness    = -2.54223004346344
# Change     = 0.0006847836854761979
#
#
# Generation = 504
# Fitness    = -2.541692288276293
# Change     = 0.0005377551871470487
#
#
# Generation = 505
# Fitness    = -2.540238930438706
# Change     = 0.0014533578375868217
#
#
# Generation = 506
# Fitness    = -2.5392541858823354
# Change     = 0.0009847445563706536
#
#
# Generation = 507
# Fitness    = -2.5366638137060655
# Change     = 0.002590372176269895
#
#
# Generation = 508
# Fitness    = -2.5366638137060655
# Change     = 0.0
#
#
# Generation = 509
# Fitness    = -2.5355995295948404
# Change     = 0.0010642841112251666
#
#
# Generation = 510
# Fitness    = -2.5351208936116643
# Change     = 0.0004786359831761011
#
#
# Generation = 511
# Fitness    = -2.5345437014129684
# Change     = 0.0005771921986958972
#
#
# Generation = 512
# Fitness    = -2.534221218157131
# Change     = 0.0003224832558372803
#
#
# Generation = 513
# Fitness    = -2.532920311064395
# Change     = 0.0013009070927361144
#
#
# Generation = 514
# Fitness    = -2.532342458925654
# Change     = 0.000577852138741175
#
#
# Generation = 515
# Fitness    = -2.5319686163251807
# Change     = 0.0003738426004731288
#
#
# Generation = 516
# Fitness    = -2.531328771831768
# Change     = 0.0006398444934125891
#
#
# Generation = 517
# Fitness    = -2.530204596392552
# Change     = 0.0011241754392159464
#
#
# Generation = 518
# Fitness    = -2.528848227134388
# Change     = 0.0013563692581639586
#
#
# Generation = 519
# Fitness    = -2.52785317034647
# Change     = 0.0009950567879180028
#
#
# Generation = 520
# Fitness    = -2.527229379789917
# Change     = 0.0006237905565531499
#
#
# Generation = 521
# Fitness    = -2.526405430390115
# Change     = 0.0008239493998019043
#
#
# Generation = 522
# Fitness    = -2.5262329697487815
# Change     = 0.00017246064133358274
#
#
# Generation = 523
# Fitness    = -2.525561034355072
# Change     = 0.0006719353937096884
#
#
# Generation = 524
# Fitness    = -2.524953900546857
# Change     = 0.0006071338082147548
#
#
# Generation = 525
# Fitness    = -2.5245901597438376
# Change     = 0.0003637408030194855
#
#
# Generation = 526
# Fitness    = -2.5244289652454652
# Change     = 0.00016119449837237454
#
#
# Generation = 527
# Fitness    = -2.523915555746972
# Change     = 0.0005134094984931004
#
#
# Generation = 528
# Fitness    = -2.5232332851619113
# Change     = 0.0006822705850608735
#
#
# Generation = 529
# Fitness    = -2.522682625243375
# Change     = 0.0005506599185363115
#
#
# Generation = 530
# Fitness    = -2.5204104286306124
# Change     = 0.002272196612762567
#
#
# Generation = 531
# Fitness    = -2.5197651981013665
# Change     = 0.0006452305292459215
#
#
# Generation = 532
# Fitness    = -2.518705544402684
# Change     = 0.001059653698682439
#
#
# Generation = 533
# Fitness    = -2.517820492905318
# Change     = 0.0008850514973661738
#
#
# Generation = 534
# Fitness    = -2.5177462355968134
# Change     = 7.42573085044107e-05
#
#
# Generation = 535
# Fitness    = -2.51730298254861
# Change     = 0.00044325304820347355
#
#
# Generation = 536
# Fitness    = -2.516719843462378
# Change     = 0.0005831390862320873
#
#
# Generation = 537
# Fitness    = -2.5163569155844616
# Change     = 0.0003629278779162526
#
#
# Generation = 538
# Fitness    = -2.515625988907464
# Change     = 0.0007309266769977008
#
#
# Generation = 539
# Fitness    = -2.5151192381656005
# Change     = 0.0005067507418634598
#
#
# Generation = 540
# Fitness    = -2.5148799340933583
# Change     = 0.00023930407224215244
#
#
# Generation = 541
# Fitness    = -2.514577415613166
# Change     = 0.0003025184801921377
#
#
# Generation = 542
# Fitness    = -2.5135420263833055
# Change     = 0.0010353892298606837
#
#
# Generation = 543
# Fitness    = -2.512075667545697
# Change     = 0.0014663588376082615
#
#
# Generation = 544
# Fitness    = -2.5116226637842667
# Change     = 0.0004530037614305371
#
#
# Generation = 545
# Fitness    = -2.5110475041564406
# Change     = 0.0005751596278260607
#
#
# Generation = 546
# Fitness    = -2.5103994902881572
# Change     = 0.0006480138682833925
#
#
# Generation = 547
# Fitness    = -2.509120532755648
# Change     = 0.001278957532509395
#
#
# Generation = 548
# Fitness    = -2.5086624482609907
# Change     = 0.0004580844946571183
#
#
# Generation = 549
# Fitness    = -2.5077706573370087
# Change     = 0.0008917909239820609
#
#
# Generation = 550
# Fitness    = -2.507449081061013
# Change     = 0.0003215762759958274
#
#
# Generation = 551
# Fitness    = -2.5071786528887876
# Change     = 0.0002704281722252233
#
#
# Generation = 552
# Fitness    = -2.50635639673607
# Change     = 0.000822256152717582
#
#
# Generation = 553
# Fitness    = -2.505481398836998
# Change     = 0.000874997899071861
#
#
# Generation = 554
# Fitness    = -2.504275652173898
# Change     = 0.00120574666310036
#
#
# Generation = 555
# Fitness    = -2.504204376558143
# Change     = 7.127561575481778e-05
#
#
# Generation = 556
# Fitness    = -2.5021204977781366
# Change     = 0.0020838787800063763
#
#
# Generation = 557
# Fitness    = -2.499910785210405
# Change     = 0.0022097125677316143
#
#
# Generation = 558
# Fitness    = -2.4997357883751246
# Change     = 0.00017499683528043875
#
#
# Generation = 559
# Fitness    = -2.49911450666576
# Change     = 0.0006212817093644851
#
#
# Generation = 560
# Fitness    = -2.4984035779163123
# Change     = 0.0007109287494477812
#
#
# Generation = 561
# Fitness    = -2.4982417281170233
# Change     = 0.00016184979928901555
#
#
# Generation = 562
# ...
#
#
# Generation = 2179
# Fitness    = -2.046932888342727
# Change     = 0.0
#
#
# Generation = 2180
# Fitness    = -2.046794380360386
# Change     = 0.00013850798234082973
#
#
# Generation = 2181
# Fitness    = -2.046794380360386
# Change     = 0.0
#
#
# Generation = 2182
# Fitness    = -2.046794380360386
# Change     = 0.0
#
#
# Generation = 2183
# Fitness    = -2.046546893930438
# Change     = 0.00024748642994820713
#
#
# Generation = 2184
# Fitness    = -2.046546893930438
# Change     = 0.0
#
#
# Generation = 2185
# Fitness    = -2.046546893930438
# Change     = 0.0
#
#
# Generation = 2186
# Fitness    = -2.0463487533283837
# Change     = 0.00019814060205414208
#
#
# Generation = 2187
# Fitness    = -2.046167936163427
# Change     = 0.00018081716495688127
#
#
# Generation = 2188
# Fitness    = -2.046167936163427
# Change     = 0.0
#
#
# Generation = 2189
# Fitness    = -2.046042477246342
# Change     = 0.00012545891708493073
#
#
# Generation = 2190
# Fitness    = -2.0457153204585747
# Change     = 0.00032715678776717994
#
#
# Generation = 2191
# Fitness    = -2.0454951099117453
# Change     = 0.00022021054682941354
#
#
# Generation = 2192
# Fitness    = -2.045433726882262
# Change     = 6.138302948333063e-05
#
#
# Generation = 2193
# Fitness    = -2.045354898154297
# Change     = 7.882872796516338e-05
#
#
# Generation = 2194
# Fitness    = -2.045354898154297
# Change     = 0.0
#
#
# Generation = 2195
# Fitness    = -2.045127807321358
# Change     = 0.00022709083293870336
#
#
# Generation = 2196
# Fitness    = -2.045127807321358
# Change     = 0.0
#
#
# Generation = 2197
# Fitness    = -2.045073906324094
# Change     = 5.390099726421127e-05
#
#
# Generation = 2198
# Fitness    = -2.044717992302329
# Change     = 0.0003559140217648249
#
#
# Generation = 2199
# Fitness    = -2.044717992302329
# Change     = 0.0
#
#
# Generation = 2200
# Fitness    = -2.044439632459068
# Change     = 0.0002783598432611889
#
#
# Generation = 2201
# Fitness    = -2.044439632459068
# Change     = 0.0
#
#
# Generation = 2202
# Fitness    = -2.044439632459068
# Change     = 0.0
#
#
# Generation = 2203
# Fitness    = -2.0441934777650843
# Change     = 0.00024615469398359124
#
#
# Generation = 2204
# Fitness    = -2.0441934777650843
# Change     = 0.0
#
#
# Generation = 2205
# Fitness    = -2.0439656210554022
# Change     = 0.00022785670968206162
#
#
# Generation = 2206
# Fitness    = -2.0439451053495468
# Change     = 2.05157058554839e-05
#
#
# Generation = 2207
# Fitness    = -2.0438027592921815
# Change     = 0.0001423460573652946
#
#
# Generation = 2208
# Fitness    = -2.043730395394423
# Change     = 7.236389775844287e-05
#
#
# Generation = 2209
# Fitness    = -2.0434349296318084
# Change     = 0.00029546576261463287
#
#
# Generation = 2210
# Fitness    = -2.0434349296318084
# Change     = 0.0
#
#
# Generation = 2211
# Fitness    = -2.043277793973801
# Change     = 0.00015713565800723472
#
#
# Generation = 2212
# Fitness    = -2.043018877294022
# Change     = 0.00025891667977928634
#
#
# Generation = 2213
# Fitness    = -2.042783105880758
# Change     = 0.00023577141326391882
#
#
# Generation = 2214
# Fitness    = -2.042700193039244
# Change     = 8.291284151384914e-05
#
#
# Generation = 2215
# Fitness    = -2.042700193039244
# Change     = 0.0
#
#
# Generation = 2216
# Fitness    = -2.0424697012497797
# Change     = 0.0002304917894644376
#
#
# Generation = 2217
# Fitness    = -2.0423354635315203
# Change     = 0.00013423771825937791
#
#
# Generation = 2218
# Fitness    = -2.0423354635315203
# Change     = 0.0
#
#
# Generation = 2219
# Fitness    = -2.0422123489550557
# Change     = 0.00012311457646463353
#
#
# Generation = 2220
# Fitness    = -2.0421426501271402
# Change     = 6.969882791540982e-05
#
#
# Generation = 2221
# Fitness    = -2.0419872294377805
# Change     = 0.00015542068935969766
#
#
# Generation = 2222
# Fitness    = -2.0419872294377805
# Change     = 0.0
#
#
# Generation = 2223
# Fitness    = -2.0416258709524024
# Change     = 0.0003613584853781049
#
#
# Generation = 2224
# Fitness    = -2.0416258709524024
# Change     = 0.0
#
#
# Generation = 2225
# Fitness    = -2.0416258709524024
# Change     = 0.0
#
#
# Generation = 2226
# Fitness    = -2.0416258709524024
# Change     = 0.0
#
#
# Generation = 2227
# Fitness    = -2.041564495541849
# Change     = 6.137541055339923e-05
#
#
# Generation = 2228
# Fitness    = -2.0414324128275285
# Change     = 0.00013208271432052499
#
#
# Generation = 2229
# Fitness    = -2.0414324128275285
# Change     = 0.0
#
#
# Generation = 2230
# Fitness    = -2.0414324128275285
# Change     = 0.0
#
#
# Generation = 2231
# Fitness    = -2.0411394577195505
# Change     = 0.00029295510797799906
#
#
# Generation = 2232
# Fitness    = -2.040729217553454
# Change     = 0.00041024016609636504
#
#
# Generation = 2233
# Fitness    = -2.040729217553454
# Change     = 0.0
#
#
# Generation = 2234
# Fitness    = -2.040729217553454
# Change     = 0.0
#
#
# Generation = 2235
# Fitness    = -2.0404964131149432
# Change     = 0.00023280443851092514
#
#
# Generation = 2236
# Fitness    = -2.0404964131149432
# Change     = 0.0
#
#
# Generation = 2237
# Fitness    = -2.0404256514271455
# Change     = 7.076168779773795e-05
#
#
# Generation = 2238
# Fitness    = -2.0403523197891222
# Change     = 7.333163802325515e-05
#
#
# Generation = 2239
# Fitness    = -2.0401613652446837
# Change     = 0.00019095454443851523
#
#
# Generation = 2240
# Fitness    = -2.0401613652446837
# Change     = 0.0
#
#
# Generation = 2241
# Fitness    = -2.040041219531564
# Change     = 0.00012014571311969036
#
#
# Generation = 2242
# Fitness    = -2.0397536349633745
# Change     = 0.00028758456818955835
#
#
# Generation = 2243
# Fitness    = -2.0396057279124244
# Change     = 0.00014790705095002465
#
#
# Generation = 2244
# Fitness    = -2.0395802903648534
# Change     = 2.543754757100558e-05
#
#
# Generation = 2245
# Fitness    = -2.039182670368087
# Change     = 0.00039761999676635185
#
#
# Generation = 2246
# Fitness    = -2.039182670368087
# Change     = 0.0
#
#
# Generation = 2247
# Fitness    = -2.039150471587018
# Change     = 3.219878106897056e-05
#
#
# Generation = 2248
# Fitness    = -2.039150471587018
# Change     = 0.0
#
#
# Generation = 2249
# Fitness    = -2.039149294239728
# Change     = 1.1773472903264803e-06
#
#
# Generation = 2250
# Fitness    = -2.039149294239728
# Change     = 0.0
#
#
# Generation = 2251
# Fitness    = -2.0386379989577597
# Change     = 0.0005112952819681382
#
#
# Generation = 2252
# Fitness    = -2.0386379989577597
# Change     = 0.0
#
#
# Generation = 2253
# Fitness    = -2.0386379989577597
# Change     = 0.0
#
#
# Generation = 2254
# Fitness    = -2.038535689281142
# Change     = 0.00010230967661772894
#
#
# Generation = 2255
# Fitness    = -2.0384898649795926
# Change     = 4.582430154931316e-05
#
#
# Generation = 2256
# Fitness    = -2.0384898649795926
# Change     = 0.0
#
#
# Generation = 2257
# Fitness    = -2.0384202234950557
# Change     = 6.964148453691976e-05
#
#
# Generation = 2258
# Fitness    = -2.0384202234950557
# Change     = 0.0
#
#
# Generation = 2259
# Fitness    = -2.0383231881924777
# Change     = 9.703530257798576e-05
#
#
# Generation = 2260
# Fitness    = -2.038101599194495
# Change     = 0.00022158899798263576
#
#
# Generation = 2261
# Fitness    = -2.037820007701781
# Change     = 0.0002815914927141172
#
#
# Generation = 2262
# Fitness    = -2.037820007701781
# Change     = 0.0
#
#
# Generation = 2263
# Fitness    = -2.0377347135344386
# Change     = 8.529416734237572e-05
#
#
# Generation = 2264
# Fitness    = -2.0376128441503862
# Change     = 0.00012186938405234216
#
#
# Generation = 2265
# Fitness    = -2.0376128441503862
# Change     = 0.0
#
#
# Generation = 2266
# Fitness    = -2.0375450867069356
# Change     = 6.77574434506667e-05
#
#
# Generation = 2267
# Fitness    = -2.037012584454117
# Change     = 0.0005325022528186452
#
#
# Generation = 2268
# Fitness    = -2.037011340109381
# Change     = 1.2443447361398796e-06
#
#
# Generation = 2269
# Fitness    = -2.0368564684541415
# Change     = 0.00015487165523930813
#
#
# Generation = 2270
# Fitness    = -2.0366542054696026
# Change     = 0.00020226298453884795
#
#
# Generation = 2271
# Fitness    = -2.0366542054696026
# Change     = 0.0
#
#
# Generation = 2272
# Fitness    = -2.0366542054696026
# Change     = 0.0
#
#
# Generation = 2273
# Fitness    = -2.0366542054696026
# Change     = 0.0
#
#
# Generation = 2274
# Fitness    = -2.0364216186055764
# Change     = 0.00023258686402627404
#
#
# Generation = 2275
# Fitness    = -2.0364216186055764
# Change     = 0.0
#
#
# Generation = 2276
# Fitness    = -2.03612663280012
# Change     = 0.0002949858054561716
#
#
# Generation = 2277
# Fitness    = -2.0360018170435135
# Change     = 0.00012481575660672206
#
#
# Generation = 2278
# Fitness    = -2.0356612696880747
# Change     = 0.00034054735543875836
#
#
# Generation = 2279
# Fitness    = -2.035520688386407
# Change     = 0.00014058130166771932
#
#
# Generation = 2280
# Fitness    = -2.035511182192182
# Change     = 9.50619422512844e-06
#
#
# Generation = 2281
# Fitness    = -2.0352568462058587
# Change     = 0.0002543359863231842
#
#
# Generation = 2282
# Fitness    = -2.0352568462058587
# Change     = 0.0
#
#
# Generation = 2283
# Fitness    = -2.0352126830858968
# Change     = 4.416311996191524e-05
#
#
# Generation = 2284
# Fitness    = -2.0352126830858968
# Change     = 0.0
#
#
# Generation = 2285
# Fitness    = -2.035210674876408
# Change     = 2.0082094889239954e-06
#
#
# Generation = 2286
# Fitness    = -2.0350194783234135
# Change     = 0.0001911965529943771
#
#
# Generation = 2287
# Fitness    = -2.0349464755968185
# Change     = 7.300272659493956e-05
#
#
# Generation = 2288
# Fitness    = -2.034712302777184
# Change     = 0.00023417281963444836
#
#
# Generation = 2289
# Fitness    = -2.0345384557793094
# Change     = 0.0001738469978747048
#
#
# Generation = 2290
# Fitness    = -2.0343689463949373
# Change     = 0.00016950938437210183
#
#
# Generation = 2291
# Fitness    = -2.0342554029426347
# Change     = 0.0001135434523025225
#
#
# Generation = 2292
# Fitness    = -2.0340659701792263
# Change     = 0.00018943276340843695
#
#
# Generation = 2293
# Fitness    = -2.0338766390239567
# Change     = 0.00018933115526964528
#
#
# Generation = 2294
# Fitness    = -2.0338766390239567
# Change     = 0.0
#
#
# Generation = 2295
# Fitness    = -2.0337224644160092
# Change     = 0.00015417460794742155
#
#
# Generation = 2296
# Fitness    = -2.0337224644160092
# Change     = 0.0
#
#
# Generation = 2297
# Fitness    = -2.0337224644160092
# Change     = 0.0
#
#
# Generation = 2298
# Fitness    = -2.033449373163625
# Change     = 0.0002730912523842832
#
#
# Generation = 2299
# Fitness    = -2.033449373163625
# Change     = 0.0
#
#
# Generation = 2300
# Fitness    = -2.0333221569447066
# Change     = 0.00012721621891831347
#
#
# Generation = 2301
# Fitness    = -2.0333221569447066
# Change     = 0.0
#
#
# Generation = 2302
# Fitness    = -2.0333221569447066
# Change     = 0.0
#
#
# Generation = 2303
# Fitness    = -2.0330958442130305
# Change     = 0.0002263127316761704
#
#
# Generation = 2304
# Fitness    = -2.0328961257605243
# Change     = 0.00019971845250621456
#
#
# Generation = 2305
# Fitness    = -2.0328920337775984
# Change     = 4.09198292583568e-06
#
#
# Generation = 2306
# Fitness    = -2.0328234366082847
# Change     = 6.859716931373327e-05
#
#
# Generation = 2307
# Fitness    = -2.03281313467485
# Change     = 1.0301933434764265e-05
#
#
# Generation = 2308
# Fitness    = -2.03223875850337
# Change     = 0.0005743761714800399
#
#
# Generation = 2309
# Fitness    = -2.032125252228233
# Change     = 0.00011350627513673217
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-e4254eb33b81> in <module>
#      60
#      61 # Running the GA to optimize the parameters of the function.
# ---> 62 ga_instance.run()
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pygad/pygad.py in run(self)
#     363             # If the callback_generation attribute is not None, then cal the callback function after the generation.
#     364             if not (self.callback_generation is None):
# --> 365                 r = self.callback_generation(self)
#     366                 if type(r) is str and r.lower() == "stop":
#     367                     break
#
# <ipython-input-9-e4254eb33b81> in callback_generation(ga_instance)
#      42     print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
#      43     print("\n")
# ---> 44     last_fitness = ga_instance.best_solution()[1]
#      45
#      46 # Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pygad/pygad.py in best_solution(self)
#     702         # Getting the best solution after finishing all generations.
#     703         # At first, the fitness is calculated for each solution in the final generation.
# --> 704         fitness = self.cal_pop_fitness()
#     705         # Then return the index of that solution corresponding to the best fitness.
#     706         best_match_idx = numpy.where(fitness == numpy.max(fitness))[0][0]
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pygad/pygad.py in cal_pop_fitness(self)
#     304         # Calculating the fitness value of each solution in the current population.
#     305         for sol_idx, sol in enumerate(self.population):
# --> 306             fitness = self.fitness_func(sol, sol_idx)
#     307             pop_fitness.append(fitness)
#     308
#
# <ipython-input-6-6ef9f85f0027> in fitness_function(delta, solution_idx)
#      10 def fitness_function(delta, solution_idx):
#      11     influence = incre_ps(delta, data)
# ---> 12     mae = -np.sqrt(np.mean((true_effect - influence)**2))
#      13     return np.mean(mae)
#      14
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3113             pass
#    3114         else:
# -> 3115             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3116
#    3117     return _methods._mean(a, axis=axis, dtype=dtype,
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11214         return self._reduce(
# > 11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#   11217
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      67             try:
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#      71                 # we want to transform an object array
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#     127             return result
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     533         or is_timedelta64_dtype(dtype)
#     534         or is_datetime64_dtype(dtype)
# --> 535         or is_datetime64tz_dtype(dtype)
#     536     ):
#     537         dtype_sum = np.float64
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_datetime64tz_dtype(arr_or_dtype)
#     436     if arr_or_dtype is None:
#     437         return False
# --> 438     return DatetimeTZDtype.is_dtype(arr_or_dtype)
#     439
#     440
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#     271         dtype = getattr(dtype, "dtype", dtype)
#     272
# --> 273         if isinstance(dtype, (ABCSeries, ABCIndexClass, ABCDataFrame, np.dtype)):
#     274             # https://github.com/pandas-dev/pandas/issues/22960
#     275             # avoid passing data to `construct_from_string`. This could
#
# ~/.conda/envs/phd_env/lib/python3.7/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#       8     # https://github.com/python/mypy/issues/1006
#       9     # error: 'classmethod' used with a non-method
# ---> 10     @classmethod  # type: ignore
#      11     def _check(cls, inst) -> bool:
#      12         return getattr(inst, attr, "_typ") in comp
#
# KeyboardInterrupt:

# %% [markdown]
# ## Optimization ATE using genetic algorithm

# %%
def incre_ps(delta, data):
    q1 = (delta * data['p1']) / (delta * data['p1'] + data['p0'])
    q1 = abs(q1)
    a0 = (1-q1)*data['w0']*(data['cf0'] - data[outcome])
    a1 = q1*data['w1']*(data['cf1'] - data[outcome])    
    influence = a1 - a0
    return influence


def fitness_function(delta, solution_idx):
    influence = incre_ps(delta, data)
    mae = -np.sqrt(np.mean((true_effect - influence)**2))
    return np.mean(mae)

# %%
index_ = 1

data = utils.load_data(cf.IHDP_TRAIN, index_)
data_test = utils.load_data(cf.IHDP_TEST, index_)
data_whole = pd.concat([data, data_test], sort=False)
## Fit treatment
model_t = LogisticRegression()
model_t.fit(data_whole[cov], data_whole[treatment])

## Fit outcome
model_y = GradientBoostingRegressor(random_state=0, n_estimators = 5000)
model_y.fit(data_whole[features], data_whole[outcome])

data['p1'] = model_t.predict_proba(data[cov])[:,1]
data['p0'] = 1 - data['p1']

## Compute counterfactual outcome with no treatment
data_pos = data.copy()
data_pos[treatment] = 1
data['cf1'] = model_y.predict(data_pos[features])

## Compute counterfactual outcome with treatment
data_neg = data.copy()
data_neg[treatment] = 0
data['cf0'] = model_y.predict(data_neg[features])

data['ips_weight'] = (data[treatment] / data['p1'] + (1 - data[treatment]) /
                      (1 - data['p1']))

data['w0'] = data['ips_weight']*data[treatment]
data['w1'] = data['ips_weight']*(1 - data[treatment])

true_effect = data['mu1'] - data['mu0']

# %%
function_inputs = np.random.rand(data.shape[0]) # Function inputs.

num_generations = 2000 # Number of generations.
num_parents_mating = 100 # Number of solutions to be selected as parents in the mating pool.

sol_per_pop = 2500 # Number of solutions in the population.
num_genes = len(function_inputs)

init_range_low = -100
init_range_high = 100

parent_selection_type = "sss" # Type of parent selection.
keep_parents = -1 # Number of parents to keep in the next population. -1 means keep all parents and 0 means keep nothing.

crossover_type = "single_point" # Type of the crossover operator.

mutation_type = "random" # Type of the mutation operator.
mutation_percent_genes = 10 # Percentage of genes to mutate. This parameter has no action if the parameter mutation_num_genes exists or when mutation_type is None.
last_fitness = 0
def callback_generation(ga_instance):
    global last_fitness
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Change     = {change}".format(change=ga_instance.best_solution()[1] - last_fitness))
    print("\n")
    last_fitness = ga_instance.best_solution()[1]
    if last_fitness <=  0.001:
        break 

# Creating an instance of the GA class inside the ga module. Some parameters are initialized within the constructor.
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating, 
                       fitness_func=fitness_function,
                       sol_per_pop=sol_per_pop, 
                       num_genes=num_genes,
                       init_range_low=init_range_low,
                       init_range_high=init_range_high,
                       parent_selection_type=parent_selection_type,
                       keep_parents=keep_parents,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       callback_generation=callback_generation)

# Running the GA to optimize the parameters of the function.
ga_instance.run()
# Out:
# Generation = 1
# Fitness    = -5.146240617048819
# Change     = -5.146240617048819
#
#
# Generation = 2
# Fitness    = -5.146240617048819
# Change     = 0.0
#
#
# Generation = 3
# Fitness    = -4.074847973786304
# Change     = 1.0713926432625147
